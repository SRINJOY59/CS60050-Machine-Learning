# %% [markdown]
# # Programming Assignment 1

# %% [markdown]
# In Part 1, you have to implement a linear regression model to predict the price of a house based on various input features.
#
# You have to write your code in this jupyter notebook and submit the solved jupyter notebook with the file name \<Roll_No\>_A1_1.ipynb for evaluation. You have to enter your code only in those cells which are marked as ```## CODE REQUIRED ##```, and you have to write your code only between ```### START CODE HERE ###``` and ```### END CODE HERE ###``` comments.

# %% [markdown]
# ## Part 1: Linear Regression
#
# ### Problem Statement
# A real estate company is building a machine learning model to determine the price of a house. The model will take various information regarding a house as input features and predict the price per unit area. They decided to use the linear regression as the machine learning model. Your task is to help the company to build the model.
# Given various features of a house, you will create a linear regression model to predict the price of the house.
#
# ### Data Description
#
# Dataset Filename: `housing_dataset.csv`
#
# Attributes Information:
# 1. CRIM: per capita crime rate by town
# 2. ZN: proportion of residential land zoned for lots over 25,000 sq.ft.
# 3. INDUS: proportion of non-­retail business acres per town
# 4. CHAS: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# 5. NOX: nitric oxides concentration (parts per 10 million)
# 6. RM: average number of rooms per dwelling
# 7. AGE: proportion of owner­occupied units built prior to 1940
# 8. DIS: weighted distances to five Boston employment centres
# 9. RAD: index of accessibility to radial highways
# 10. TAX: full-­value property-­tax rate per $10,000
#
# 11. PTRATIO: pupil-­teacher ratio by town
# 12. B: 1000(Bk ­- 0.63)^2 where Bk is the proportion of blacks by town
# 13. LSTAT: % lower status of the population
#
# Target Variable: MEDV: Median value of owner-­occupied homes in $1000's
#
#
# These are the following steps or functions that you have to complete to create and train the linear regression model:
# 1. Reading the data
# 2. Computing the loss function
# 3. Computing the gradient of the loss
# 4. Training the model using Batch Gradient Descent

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import copy
import math
import random

# %% [markdown]
# ### 1.1. Reading the data

# %% [markdown]
# In the following function ```load_data```, you have to read the data from the file and store the data into a pandas dataframe. Then you have to create two numpy arrays $X$ and $y$ from the dataframe:
#
# + $X$: Input data of the shape (number of samples, number of input features)
# + $y$: Target variable of the shape (number of samples,)

# %%
## CODE REQUIRED ##

def load_data(filepath):
    """
    This function loads the data into a pandas dataframe and coverts it into X and y numpy arrays

    Args:
        filepath: File path as a string
    Returns:
        X: Input data of the shape (# of samples, # of input features)
        y: Target variable of the shape (# of sample,)
    """

    ### START CODE HERE ###
    df = pd.read_csv(filepath)
    X = df.iloc[:,:-1].to_numpy()
    y = df.iloc[:, -1].to_numpy()
    ### END CODE HERE ###

    return X,y

filepath = "housing_dataset.csv"
### START CODE HERE ###
## set the file path

### END CODE HERE ###
X, y = load_data(filepath)

print("Shape of X: ",X.shape, "Shape of y: ",y.shape)
# Out:
# Shape of X:  (404, 13) Shape of y:  (404,)

# %% [markdown]
# We need to pre-process the data. We are using min-max scaler to scale the input data ($X$).
#
# After that, we split the data (```X``` and ```y```) into a training dataset (```X_train``` and ```y_train```) and test dataset (```X_test``` and ```y_test```).

# %%
## Data scaling and train-test split

def train_test_split(X, y, test_size=0.25, random_state=None):
    if random_state is not None:
        np.random.seed(random_state)
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)

    split_index = int(X.shape[0] * (1 - test_size))

    train_indices = indices[:split_index]
    test_indices = indices[split_index:]

    X_train = X[train_indices]
    X_test = X[test_indices]
    y_train = y[train_indices]
    y_test = y[test_indices]

    return X_train, X_test, y_train, y_test

def min_max_scaler(X, feature_range=(0, 1)):
    X_min = np.min(X, axis=0)
    X_max = np.max(X, axis=0)

    X_scaled = (X-X_min)/(X_max-X_min)

    return X_scaled


X = min_max_scaler(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
print("Shape of X_train: ",X_train.shape, "Shape of y_train: ",y_train.shape)
print("Shape of X_test: ",X_test.shape, "Shape of y_test: ",y_test.shape)
# Out:
# Shape of X_train:  (303, 13) Shape of y_train:  (303,)
# Shape of X_test:  (101, 13) Shape of y_test:  (101,)

# %% [markdown]
# ### 1.2. Computing the Loss Function

# %% [markdown]
# In linear regression, the model parameters are:
#
# + $w$: Parameters of the linear regression model (excluding the bias) of the shape (1, number of features)
#
# + $b$: Bias parameter (scalar) of the linear regression model
#
# Both $w$ and $b$ are numpy arrays.
#
# Given the model parameters $w$ and $b$, the prediction for an input sample $X^i$ is:
# $$h_{w,b}(X^i) = w \cdot X^i + b$$
# where $X^i$ is the $i^{th}$ training sample with shape (number of features,1)
#
# For linear regression, you have to implement and compute Mean Squarred Error loss fucntion:
# $$ L_{w,b}(X) = \sum_{i=1}^{m}(y^i - h_{w,b}(X^i))^2 $$
# where $y^i$ is the true target value for the $i^{th}$ sample and $h_{w,b}(X^i)$ is the predicted value for the $i^{th}$ sample using the parameters $w$ and $b$.
#
# $w$ is the list of parameters excluding the bias and $b$ is the bias term.

# %%
## CODE REQUIRED ##

def loss_function(X, y, w, b):
    """
    Computes the cost function for linear regression.

    Args:
        X: Input data of the shape (# of training samples, # of input features)
        y: Target variable of the shape (# of training sample,)
        w: Parameters of the linear regression model (excluding the bias) of the shape (1, number of features)
        b: Bias parameter (scalar) of the linear regression model

    Returns
        loss: The loss function value of using w and b as the parameters to fit the data points in X and y
    """
    # number of training examples
    m = X.shape[0]

    ### START CODE HERE ###
    y_hat = np.dot(X, w.T) + b
    y_hat = np.squeeze(y_hat)
    loss = (1 / (2 * m)) * np.sum((y_hat - y) ** 2)

    ### END CODE HERE ###
    return loss

# %% [markdown]
# ### 1.3. Comptuing the Gradient of the Loss
#
# In this following function ```compute_gradient```, you have to compute the gradients $\frac{\partial L}{\partial w}$ and $\frac{\partial L}{\partial b}$ of the loss $L$ w.r.t. $w$ and $b$. More specifically, you have to iterate over every training example and compute the gradients of the loss for that training example. Finally, aggregate the gradient values for all the training examples and take the average. The gradients can be computed as:
# $$\frac{\partial L}{\partial w} = \frac{1}{m} \sum_{i=1}^m (h_{w,b}(X^i)-y^i)X^i$$
#
# $$\frac{\partial L}{\partial b} = \frac{1}{m} \sum_{i=1}^{m} (h_{w,b}(X^i)-y^i)$$

# %%
## CODE REQUIRED ##

def compute_gradient(X, y, w, b):
    """
    Computes the gradient values
    Args:
       X: Input data of the shape (# of training samples, # of input features)
       y: Target variable of the shape (# of training sample,)
       w: Parameters of the linear regression model (excluding the bias) of the shape (1, number of features)
       b: Bias parameter of the linear regression model of the shape (1,1) or a scaler
    Returns:
       dL_dw : The gradient of the cost w.r.t. the parameters w with shape same as w
       dL_db : The gradient of the cost w.r.t. the parameter b with shape same as b
    """

    # Number of training examples
    m = X.shape[0]

    dL_dw = 0
    dL_db = 0

    ### START CODE HERE ###
    y_hat = np.dot(X, w.T) + b
    y_hat = np.squeeze(y_hat)
    dL_dw = -(1/m) * np.dot((y - y_hat).T, X)  # Shape (n,)
    dL_db = -(1/m) * np.sum(y - y_hat)
    ### END CODE HERE ###
    return dL_dw, dL_db

# %% [markdown]
# ### 1.4. Training the Model using Batch Gradient Descent

# %% [markdown]
# Finally, you have to implement the batch gradient descent algorithm to train and learn the parameters of the linear regression model. You have to use ```loss_function``` and ```compute_gradient``` functions that you have implemented earlier in this assignment.
#
# In this ```batch_gradient_descent``` function, you have to compute the gradient for the training samples and update the parameters $w$ and $b$ in every iteration:
#
# + $w \leftarrow w - \alpha \frac{\partial L}{\partial w}$
#
# + $b \leftarrow b - \alpha \frac{\partial L}{\partial b}$
#
# Additionally, you have compute the loss function values in every iteration and store it in the list variable ```loss_hist``` and print the loss value after every 100 iterations during the training process.

# %%
## CODE REQUIRED ##

def batch_gradient_descent(X, y, w_initial, b_initial, alpha, num_iters):
    """
    Batch gradient descent to learn the parameters (w and b) of the linear regression model and to print loss values
    every 100 iterations

    Args:
        X: Input data of the shape (# of training samples, # of input features)
        y: Target variable of the shape (# of training sample,)
        w_initial: Initial parameters of the linear regression model (excluding the bias) of the shape (1, number of features)
        b_initial: Initial bias parameter (scalar) of the linear regression model
        alpha: Learning rate
        num_iters: number of iterations
    Returns
        w: Updated values of parameters of the model after training
        b: Updated bias of the model after training
        loss_hist: List of loss values for every iteration
    """

    # number of training examples
    m = X.shape[0]

    # to store loss values for every iteation as a list and print loss value after every 100 iterations
    loss_hist = []

    # Initialize parameters
    w = copy.deepcopy(w_initial) ## deepcopy is used so that the updates do not change the initial variable values
    b = b_initial

    ### START CODE HERE ###

    for i in range(num_iters):
        loss = loss_function(X, y, w, b)
        loss_hist.append([[loss]])
        
        dL_dw, dL_db = compute_gradient(X, y, w, b)
        w = w - alpha*dL_dw
        b = b - alpha*dL_db
        
        
        if i%10 == 0:
            print("Loss after ", i, " epochs : ", loss)

    ### END CODE HERE ###
    

    return w, b, loss_hist

# %% [markdown]
# Now you have to intialize the model parameters ($w$ and $b$) and learning rate (```alpha```). The learning rate ```alpha``` is to be initialized as 0.001.

# %%
## CODE REQUIRED ##

def initialize_parameters():
    """
    This function randomly initializes the model parameters (w and b) and the hyperparameter alpha
    Initial w and b should be randomly sampled from a normal distribution with mean 0
    alpha should be initialized as 0.001
    Args:
        None
    Returns:
        initial_w: Initial parameters of the linear regression model (excluding the bias) of the shape (1, number of features)
        initial_b: Initial bias parameter (scalar) of the linear regression model
        alpha: Learning rate
    """

    initial_w = None
    initial_b = None
    alpha = None

    ### START CODE HERE ###

    initial_w = np.random.randn(1, X_train.shape[1])
    initial_b = np.random.randn()
    alpha = 0.001
    ### END CODE HERE ###

    return initial_w,initial_b,alpha

# %% [markdown]
# In the next cell, the model is trained using batch gradient descent algorithm for ```num_iters=10000``` iterations. You can change the number of iterations to check any improvements in the performance.

# %%
# initialize the parameters and hyperparameter
initial_w, initial_b, alpha = initialize_parameters()

#number of iterations
num_iters = 10000

w,b,loss_hist = batch_gradient_descent(X_train ,y_train, initial_w, initial_b, alpha, num_iters)
print("Updated w: ",w)
print("Updated b: ",b)
# Out:
# Loss after  0  epochs :  282.04502069891436
# Loss after  10  epochs :  266.14294155248143
# Loss after  20  epochs :  251.36713579017677
# Loss after  30  epochs :  237.63702281075953
# Loss after  40  epochs :  224.8777920484779
# Loss after  50  epochs :  213.0199897741631
# Loss after  60  epochs :  201.99913548618025
# Loss after  70  epochs :  191.75536577225446
# Loss after  80  epochs :  182.2331036749378
# Loss after  90  epochs :  173.3807517343571
# Loss after  100  epochs :  165.15040701267282
# Loss after  110  epochs :  157.49759652610118
# Loss after  120  epochs :  150.38103162307945
# Loss after  130  epochs :  143.76237995180884
# Loss after  140  epochs :  137.60605375757035
# Loss after  150  epochs :  131.8790133404097
# Loss after  160  epochs :  126.55058458753315
# Loss after  170  epochs :  121.59228957249952
# Loss after  180  epochs :  116.97768928547247
# Loss after  190  epochs :  112.68223762580865
# Loss after  200  epochs :  108.68314585046595
# Loss after  210  epochs :  104.95925672947256
# Loss after  220  epochs :  101.49092771331898
# Loss after  230  epochs :  98.25992246691273
# Loss after  240  epochs :  95.24931017095298
# Loss after  250  epochs :  92.44337203448661
# Loss after  260  epochs :  89.82751450224094
# Loss after  270  epochs :  87.38818867730889
# Loss after  280  epochs :  85.11281551409493
# Loss after  290  epochs :  82.98971636830338
# Loss after  300  epochs :  81.00804852034247
# Loss after  310  epochs :  79.15774531598956
# Loss after  320  epochs :  77.42946059366764
# Loss after  330  epochs :  75.81451709136161
# Loss after  340  epochs :  74.30485854818579
# Loss after  350  epochs :  72.89300523602255
# Loss after  360  epochs :  71.5720126755987
# Loss after  370  epochs :  70.33543330895715
# Loss after  380  epochs :  69.17728091661102
# Loss after  390  epochs :  68.09199758282925
# Loss after  400  epochs :  67.07442302657768
# Loss after  410  epochs :  66.11976612870684
# Loss after  420  epochs :  65.2235784981104
# Loss after  430  epochs :  64.38172993083897
# Loss after  440  epochs :  63.59038562661287
# Loss after  450  epochs :  62.845985036882766
# Loss after  460  epochs :  62.14522222760077
# Loss after  470  epochs :  61.48502764823108
# Loss after  480  epochs :  60.862551206296864
# Loss after  490  epochs :  60.27514655397211
# Loss after  500  epochs :  59.72035649992157
# Loss after  510  epochs :  59.19589946580851
# Loss after  520  epochs :  58.69965691265928
# Loss after  530  epochs :  58.22966166763217
# Loss after  540  epochs :  57.7840870867111
# Loss after  550  epochs :  57.361236993462086
# Loss after  560  epochs :  56.95953633827756
# Loss after  570  epochs :  56.57752252651312
# Loss after  580  epochs :  56.21383736761648
# Loss after  590  epochs :  55.86721960077832
# Loss after  600  epochs :  55.5364979558193
# Loss after  610  epochs :  55.220584710984404
# Loss after  620  epochs :  54.91846971206014
# Loss after  630  epochs :  54.62921481977859
# Loss after  640  epochs :  54.351948754838176
# Loss after  650  epochs :  54.08586231206717
# Loss after  660  epochs :  53.83020391729493
# Loss after  670  epochs :  53.58427550238939
# Loss after  680  epochs :  53.34742867567628
# Loss after  690  epochs :  53.11906116658725
# Loss after  700  epochs :  52.89861352489936
# Loss after  710  epochs :  52.685566056333904
# Loss after  720  epochs :  52.47943597758882
# Loss after  730  epochs :  52.27977477509079
# Loss after  740  epochs :  52.08616575287808
# Loss after  750  epochs :  51.89822175607064
# Loss after  760  epochs :  51.7155830573532
# Loss after  770  epochs :  51.53791539479796
# Loss after  780  epochs :  51.36490815018894
# Loss after  790  epochs :  51.19627265778715
# Loss after  800  epochs :  51.03174063419482
# Loss after  810  epochs :  50.87106272064732
# Loss after  820  epochs :  50.71400712968121
# Loss after  830  epochs :  50.56035838870437
# Loss after  840  epochs :  50.40991617352858
# Loss after  850  epochs :  50.26249422542264
# Loss after  860  epochs :  50.11791934570476
# Loss after  870  epochs :  49.9760304623217
# Loss after  880  epochs :  49.83667776325981
# Loss after  890  epochs :  49.69972189200171
# Loss after  900  epochs :  49.565033200586
# Loss after  910  epochs :  49.43249105614448
# Loss after  920  epochs :  49.30198319708787
# Loss after  930  epochs :  49.173405135384286
# Loss after  940  epochs :  49.04665960163005
# Loss after  950  epochs :  48.9216560298482
# Loss after  960  epochs :  48.798310079170214
# Loss after  970  epochs :  48.67654318975924
# Loss after  980  epochs :  48.556282170523275
# Loss after  990  epochs :  48.437458816341575
# Loss after  1000  epochs :  48.32000955269094
# Loss after  1010  epochs :  48.20387510570984
# Loss after  1020  epochs :  48.08900019587873
# Loss after  1030  epochs :  47.97533325362552
# Loss after  1040  epochs :  47.862826155286086
# Loss after  1050  epochs :  47.75143397796233
# Loss after  1060  epochs :  47.641114771924435
# Loss after  1070  epochs :  47.53182934930125
# Loss after  1080  epochs :  47.423541087892126
# Loss after  1090  epochs :  47.31621574901777
# Loss after  1100  epochs :  47.209821308404486
# Loss after  1110  epochs :  47.104327799168765
# Loss after  1120  epochs :  46.99970716603573
# Loss after  1130  epochs :  46.89593312998688
# Loss after  1140  epochs :  46.792981062590485
# Loss after  1150  epochs :  46.69082786932136
# Loss after  1160  epochs :  46.58945188122611
# Loss after  1170  epochs :  46.48883275433651
# Loss after  1180  epochs :  46.38895137627613
# Loss after  1190  epochs :  46.289789779545124
# Loss after  1200  epochs :  46.19133106100509
# Loss after  1210  epochs :  46.09355930711999
# Loss after  1220  epochs :  45.996459524541066
# Loss after  1230  epochs :  45.900017575653074
# Loss after  1240  epochs :  45.80422011872658
# Loss after  1250  epochs :  45.7090545523467
# Loss after  1260  epochs :  45.61450896381181
# Loss after  1270  epochs :  45.52057208121831
# Loss after  1280  epochs :  45.42723322896734
# Loss after  1290  epochs :  45.33448228644846
# Loss after  1300  epochs :  45.24230964967302
# Loss after  1310  epochs :  45.15070619564574
# Loss after  1320  epochs :  45.0596632492789
# Loss after  1330  epochs :  44.969172552666635
# Loss after  1340  epochs :  44.8792262365508
# Loss after  1350  epochs :  44.78981679382128
# Loss after  1360  epochs :  44.70093705490514
# Loss after  1370  epochs :  44.612580164909566
# Loss after  1380  epochs :  44.524739562392824
# Loss after  1390  epochs :  44.4374089596469
# Loss after  1400  epochs :  44.35058232438359
# Loss after  1410  epochs :  44.26425386272347
# Loss after  1420  epochs :  44.17841800339467
# Loss after  1430  epochs :  44.09306938305474
# Loss after  1440  epochs :  44.00820283265537
# Loss after  1450  epochs :  43.923813364775135
# Loss after  1460  epochs :  43.83989616185126
# Loss after  1470  epochs :  43.75644656524586
# Loss after  1480  epochs :  43.673460065087
# Loss after  1490  epochs :  43.59093229082933
# Loss after  1500  epochs :  43.508859002482474
# Loss after  1510  epochs :  43.42723608245971
# Loss after  1520  epochs :  43.34605952800245
# Loss after  1530  epochs :  43.26532544413932
# Loss after  1540  epochs :  43.185030037141665
# Loss after  1550  epochs :  43.10516960843998
# Loss after  1560  epochs :  43.02574054896811
# Loss after  1570  epochs :  42.94673933390514
# Loss after  1580  epochs :  42.868162517785905
# Loss after  1590  epochs :  42.790006729954214
# Loss after  1600  epochs :  42.712268670334176
# Loss after  1610  epochs :  42.63494510549693
# Loss after  1620  epochs :  42.55803286500149
# Loss after  1630  epochs :  42.48152883799039
# Loss after  1640  epochs :  42.4054299700218
# Loss after  1650  epochs :  42.32973326012115
# Loss after  1660  epochs :  42.25443575803681
# Loss after  1670  epochs :  42.17953456168499
# Loss after  1680  epochs :  42.10502681477057
# Loss after  1690  epochs :  42.03090970457126
# Loss after  1700  epochs :  41.95718045987333
# Loss after  1710  epochs :  41.88383634904826
# Loss after  1720  epochs :  41.81087467826013
# Loss after  1730  epochs :  41.73829278979454
# Loss after  1740  epochs :  41.66608806050038
# Loss after  1750  epochs :  41.59425790033627
# Loss after  1760  epochs :  41.5227997510145
# Loss after  1770  epochs :  41.45171108473523
# Loss after  1780  epochs :  41.38098940300482
# Loss after  1790  epochs :  41.31063223553197
# Loss after  1800  epochs :  41.24063713919654
# Loss after  1810  epochs :  41.17100169708552
# Loss after  1820  epochs :  41.10172351759167
# Loss after  1830  epochs :  41.032800233570185
# Loss after  1840  epochs :  40.96422950154935
# Loss after  1850  epochs :  40.896009000991384
# Loss after  1860  epochs :  40.828136433599965
# Loss after  1870  epochs :  40.7606095226709
# Loss after  1880  epochs :  40.693426012483215
# Loss after  1890  epochs :  40.626583667727644
# Loss after  1900  epochs :  40.560080272969735
# Loss after  1910  epochs :  40.49391363214549
# Loss after  1920  epochs :  40.42808156808698
# Loss after  1930  epochs :  40.36258192207582
# Loss after  1940  epochs :  40.29741255342276
# Loss after  1950  epochs :  40.23257133907132
# Loss after  1960  epochs :  40.168056173223995
# Loss after  1970  epochs :  40.103864966989256
# Loss after  1980  epochs :  40.03999564804808
# Loss after  1990  epochs :  39.97644616033849
# Loss after  2000  epochs :  39.913214463757036
# Loss after  2010  epochs :  39.850298533875794
# Loss after  2020  epochs :  39.78769636167403
# Loss after  2030  epochs :  39.725405953283506
# Loss after  3430  epochs :  33.341520774848895
# Loss after  3440  epochs :  33.30841688340283
# Loss after  3450  epochs :  33.27544336385771
# Loss after  3460  epochs :  33.242599445023664
# Loss after  3470  epochs :  33.20988436070728
# Loss after  3480  epochs :  33.17729734967864
# Loss after  3490  epochs :  33.14483765563871
# Loss after  3500  epochs :  33.1125045271867
# Loss after  3510  epochs :  33.08029721778785
# Loss after  3520  epochs :  33.04821498574132
# Loss after  3530  epochs :  33.01625709414834
# Loss after  3540  epochs :  32.98442281088054
# Loss after  3550  epochs :  32.95271140854849
# Loss after  3560  epochs :  32.9211221644705
# Loss after  3570  epochs :  32.88965436064158
# Loss after  3580  epochs :  32.85830728370253
# Loss after  3590  epochs :  32.82708022490947
# Loss after  3600  epochs :  32.79597248010329
# Loss after  3610  epochs :  32.764983349679476
# Loss after  3620  epochs :  32.73411213855811
# Loss after  3630  epochs :  32.70335815615404
# Loss after  3640  epochs :  32.672720716347214
# Loss after  3650  epochs :  32.64219913745334
# Loss after  3660  epochs :  32.611792742194574
# Loss after  3670  epochs :  32.58150085767051
# Loss after  3680  epochs :  32.551322815329335
# Loss after  3690  epochs :  32.5212579509392
# Loss after  3700  epochs :  32.491305604559706
# Loss after  3710  epochs :  32.46146512051365
# Loss after  3720  epochs :  32.43173584735893
# Loss after  3730  epochs :  32.40211713786066
# Loss after  3740  epochs :  32.37260834896341
# Loss after  3750  epochs :  32.343208841763726
# Loss after  3760  epochs :  32.31391798148272
# Loss after  3770  epochs :  32.284735137438915
# Loss after  3780  epochs :  32.255659683021264
# Loss after  3790  epochs :  32.22669099566233
# Loss after  3800  epochs :  32.19782845681164
# Loss after  3810  epochs :  32.16907145190923
# Loss after  3820  epochs :  32.14041937035937
# Loss after  3830  epochs :  32.111871605504405
# Loss after  3840  epochs :  32.08342755459887
# Loss after  3850  epochs :  32.05508661878371
# Loss after  3860  epochs :  32.02684820306067
# Loss after  3870  epochs :  31.998711716266836
# Loss after  3880  epochs :  31.970676571049456
# Loss after  3890  epochs :  31.942742183840753
# Loss after  3900  epochs :  31.914907974833085
# Loss after  3910  epochs :  31.887173367954116
# Loss after  3920  epochs :  31.859537790842236
# Loss after  3930  epochs :  31.832000674822154
# Loss after  3940  epochs :  31.80456145488059
# Loss after  3950  epochs :  31.777219569642178
# Loss after  3960  epochs :  31.749974461345484
# Loss after  3970  epochs :  31.722825575819268
# Loss after  3980  epochs :  31.695772362458786
# Loss after  3990  epochs :  31.668814274202354
# Loss after  4000  epochs :  31.641950767507964
# Loss after  4010  epochs :  31.615181302330175
# Loss after  4020  epochs :  31.588505342097058
# Loss after  4030  epochs :  31.561922353687347
# Loss after  4040  epochs :  31.5354318074077
# Loss after  4050  epochs :  31.509033176970142
# Loss after  4060  epochs :  31.48272593946968
# Loss after  4070  epochs :  31.456509575361984
# Loss after  4080  epochs :  31.4303835684413
# Loss after  4090  epochs :  31.40434740581846
# Loss after  4100  epochs :  31.378400577899086
# Loss after  4110  epochs :  31.352542578361817
# Loss after  4120  epochs :  31.326772904136913
# Loss after  4130  epochs :  31.301091055384713
# Loss after  4140  epochs :  31.275496535474442
# Loss after  4150  epochs :  31.249988850963124
# Loss after  4160  epochs :  31.224567511574524
# Loss after  4170  epochs :  31.199232030178397
# Loss after  4180  epochs :  31.17398192276972
# Loss after  4190  epochs :  31.148816708448162
# Loss after  4200  epochs :  31.123735909397656
# Loss after  4210  epochs :  31.098739050866083
# Loss after  4220  epochs :  31.073825661145147
# Loss after  4230  epochs :  31.048995271550318
# Loss after  4240  epochs :  31.02424741640096
# Loss after  4250  epochs :  30.999581633000567
# Loss after  4260  epochs :  30.974997461617132
# Loss after  4270  epochs :  30.950494445463626
# Loss after  4280  epochs :  30.926072130678648
# Loss after  4290  epochs :  30.9017300663072
# Loss after  4300  epochs :  30.877467804281515
# Loss after  4310  epochs :  30.85328489940212
# Loss after  4320  epochs :  30.829180909318936
# Loss after  4330  epochs :  30.805155394512575
# Loss after  4340  epochs :  30.78120791827568
# Loss after  4350  epochs :  30.757338046694468
# Loss after  4360  epochs :  30.73354534863034
# Loss after  4370  epochs :  30.709829395701632
# Loss after  4380  epochs :  30.68618976226552
# Loss after  4390  epochs :  30.66262602539994
# Loss after  4400  epochs :  30.63913776488578
# Loss after  4410  epochs :  30.615724563189065
# Loss after  4420  epochs :  30.592386005443295
# Loss after  4430  epochs :  30.569121679431937
# Loss after  4440  epochs :  30.54593117557097
# Loss after  4450  epochs :  30.522814086891632
# Loss after  4460  epochs :  30.499770009023166
# Loss after  4470  epochs :  30.47679854017579
# Loss after  4480  epochs :  30.453899281123718
# Loss after  4490  epochs :  30.43107183518829
# Loss after  4500  epochs :  30.408315808221232
# Loss after  4510  epochs :  30.385630808588086
# Loss after  4520  epochs :  30.363016447151594
# Loss after  4530  epochs :  30.340472337255363
# Loss after  4540  epochs :  30.31799809470752
# Loss after  4550  epochs :  30.295593337764526
# Loss after  4560  epochs :  30.273257687115102
# Loss after  4570  epochs :  30.250990765864238
# Loss after  4580  epochs :  30.22879219951732
# Loss after  4590  epochs :  30.206661615964332
# Loss after  4600  epochs :  30.184598645464252
# Loss after  4610  epochs :  30.16260292062941
# Loss after  4620  epochs :  30.140674076410097
# Loss after  4630  epochs :  30.11881175007915
# Loss after  4640  epochs :  30.097015581216755
# Loss after  4650  epochs :  30.075285211695228
# Loss after  4660  epochs :  30.05362028566401
# Loss after  4670  epochs :  30.032020449534695
# Loss after  4680  epochs :  30.01048535196614
# Loss after  4690  epochs :  29.98901464384976
# Loss after  4700  epochs :  29.967607978294836
# Loss after  4710  epochs :  29.94626501061396
# Loss after  4720  epochs :  29.92498539830854
# Loss after  4730  epochs :  29.903768801054486
# Loss after  4740  epochs :  29.88261488068788
# Loss after  4750  epochs :  29.861523301190786
# Loss after  4760  epochs :  29.840493728677224
# Loss after  4770  epochs :  29.819525831379107
# Loss after  4780  epochs :  29.79861927963238
# Loss after  4790  epochs :  29.77777374586318
# Loss after  4800  epochs :  29.75698890457411
# Loss after  4810  epochs :  29.73626443233068
# Loss after  4820  epochs :  29.71560000774768
# Loss after  4830  epochs :  29.694995311475722
# Loss after  4840  epochs :  29.674450026188012
# Loss after  4850  epochs :  29.653963836566902
# Loss after  4860  epochs :  29.633536429290814
# Loss after  4870  epochs :  29.61316749302114
# Loss after  4880  epochs :  29.592856718389175
# Loss after  4890  epochs :  29.572603797983216
# Loss after  4900  epochs :  29.55240842633576
# Loss after  4910  epochs :  29.532270299910678
# Loss after  4920  epochs :  29.512189117090614
# Loss after  4930  epochs :  29.492164578164346
# Loss after  4940  epochs :  29.47219638531429
# Loss after  4950  epochs :  29.45228424260412
# Loss after  4960  epochs :  29.432427855966374
# Loss after  4970  epochs :  29.41262693319022
# Loss after  4980  epochs :  29.392881183909303
# Loss after  4990  epochs :  29.373190319589586
# Loss after  5000  epochs :  29.35355405351741
# Loss after  5010  epochs :  29.33397210078748
# Loss after  5020  epochs :  29.31444417829108
# Loss after  5030  epochs :  29.29497000470424
# Loss after  5040  epochs :  29.275549300476047
# Loss after  5050  epochs :  29.256181787817052
# Loss after  5060  epochs :  29.236867190687665
# Loss after  5070  epochs :  29.21760523478673
# Loss after  5080  epochs :  29.198395647540114
# Loss after  5090  epochs :  29.179238158089376
# Loss after  5100  epochs :  29.160132497280543
# Loss after  5110  epochs :  29.141078397652922
# Loss after  5120  epochs :  29.122075593428
# Loss after  5130  epochs :  29.10312382049843
# Loss after  5140  epochs :  29.084222816417103
# Loss after  5150  epochs :  29.065372320386196
# Loss after  5160  epochs :  29.046572073246438
# Loss after  5170  epochs :  29.02782181746635
# Loss after  5180  epochs :  29.00912129713157
# Loss after  5190  epochs :  28.990470257934263
# Loss after  5200  epochs :  28.971868447162617
# Loss after  5210  epochs :  28.953315613690346
# Loss after  5220  epochs :  28.93481150796634
# Loss after  5230  epochs :  28.91635588200436
# Loss after  5240  epochs :  28.897948489372727
# Loss after  5250  epochs :  28.879589085184204
# Loss after  5260  epochs :  28.861277426085863
# Loss after  5270  epochs :  28.843013270249003
# Loss after  5280  epochs :  28.824796377359228
# Loss after  5290  epochs :  28.806626508606502
# Loss after  5300  epochs :  28.78850342667527
# Loss after  5310  epochs :  28.770426895734754
# Loss after  5320  epochs :  28.752396681429126
# Loss after  5330  epochs :  28.734412550867965
# Loss after  5340  epochs :  28.716474272616566
# Loss after  5350  epochs :  28.69858161668647
# Loss after  5360  epochs :  28.680734354526024
# Loss after  5370  epochs :  28.662932259010866
# Loss after  5380  epochs :  28.64517510443472
# Loss after  5390  epochs :  28.62746266650002
# Loss after  5400  epochs :  28.609794722308724
# Loss after  5410  epochs :  28.592171050353187
# Loss after  5420  epochs :  28.574591430507017
# Loss after  5430  epochs :  28.557055644016057
# Loss after  5440  epochs :  28.539563473489416
# Loss after  5450  epochs :  28.52211470289053
# Loss after  5460  epochs :  28.50470911752835
# Loss after  5470  epochs :  28.487346504048485
# Loss after  5480  epochs :  28.470026650424508
# Loss after  5490  epochs :  28.452749345949215
# Loss after  5500  epochs :  28.435514381226074
# Loss after  5510  epochs :  28.41832154816058
# Loss after  5520  epochs :  28.40117063995179
# Loss after  5530  epochs :  28.384061451083877
# Loss after  5540  epochs :  28.36699377731766
# Loss after  5550  epochs :  28.34996741568233
# Loss after  5560  epochs :  28.33298216446713
# Loss after  5570  epochs :  28.316037823213108
# Loss after  5580  epochs :  28.299134192704972
# Loss after  5590  epochs :  28.282271074962924
# Loss after  5600  epochs :  28.265448273234593
# Loss after  5610  epochs :  28.248665591987045
# Loss after  5620  epochs :  28.231922836898768
# Loss after  5630  epochs :  28.215219814851825
# Loss after  5640  epochs :  28.198556333923904
# Loss after  5650  epochs :  28.18193220338058
# Loss after  5660  epochs :  28.165347233667525
# Loss after  5670  epochs :  28.148801236402807
# Loss after  5680  epochs :  28.132294024369216
# Loss after  5690  epochs :  28.11582541150669
# Loss after  5700  epochs :  28.09939521290472
# Loss after  5710  epochs :  28.083003244794888
# Loss after  5720  epochs :  28.066649324543377
# Loss after  5730  epochs :  28.05033327064357
# Loss after  5740  epochs :  28.0340549027087
# Loss after  5750  epochs :  28.01781404146453
# Loss after  5760  epochs :  28.0016105087421
# Loss after  5770  epochs :  27.985444127470508
# Loss after  5780  epochs :  27.969314721669758
# Loss after  5790  epochs :  27.95322211644361
# Loss after  5800  epochs :  27.937166137972525
# Loss after  5810  epochs :  27.921146613506657
# Loss after  5820  epochs :  27.90516337135886
# Loss after  5830  epochs :  27.889216240897735
# Loss after  5840  epochs :  27.873305052540783
# Loss after  5850  epochs :  27.85742963774752
# Loss after  5860  epochs :  27.84158982901273
# Loss after  5870  epochs :  27.825785459859667
# Loss after  5880  epochs :  27.810016364833363
# Loss after  5890  epochs :  27.794282379493993
# Loss after  5900  epochs :  27.77858334041024
# Loss after  5910  epochs :  27.762919085152653
# Loss after  5920  epochs :  27.747289452287244
# Loss after  5930  epochs :  27.731694281368902
# Loss after  5940  epochs :  27.716133412934987
# Loss after  5950  epochs :  27.700606688498887
# Loss after  5960  epochs :  27.685113950543737
# Loss after  5970  epochs :  27.66965504251602
# Loss after  5980  epochs :  27.654229808819306
# Loss after  5990  epochs :  27.638838094808055
# Loss after  6000  epochs :  27.623479746781392
# Loss after  6010  epochs :  27.608154611976957
# Loss after  6020  epochs :  27.592862538564784
# Loss after  6030  epochs :  27.577603375641257
# Loss after  6040  epochs :  27.56237697322306
# Loss after  6050  epochs :  27.54718318224114
# Loss after  6060  epochs :  27.532021854534857
# Loss after  6070  epochs :  27.516892842845955
# Loss after  6080  epochs :  27.50179600081278
# Loss after  6090  epochs :  27.486731182964384
# Loss after  6100  epochs :  27.471698244714766
# Loss after  6110  epochs :  27.45669704235706
# Loss after  6120  epochs :  27.44172743305788
# Loss after  6130  epochs :  27.426789274851604
# Loss after  6140  epochs :  27.411882426634712
# Loss after  6150  epochs :  27.397006748160194
# Loss after  6160  epochs :  27.38216210003198
# Loss after  6170  epochs :  27.367348343699412
# Loss after  6180  epochs :  27.35256534145173
# Loss after  6190  epochs :  27.33781295641259
# Loss after  6200  epochs :  27.323091052534714
# Loss after  6210  epochs :  27.308399494594394
# Loss after  6220  epochs :  27.293738148186232
# Loss after  6230  epochs :  27.279106879717748
# Loss after  6240  epochs :  27.26450555640413
# Loss after  6250  epochs :  27.249934046263007
# Loss after  6260  epochs :  27.235392218109183
# Loss after  6270  epochs :  27.220879941549487
# Loss after  6280  epochs :  27.206397086977617
# Loss after  6290  epochs :  27.19194352556904
# Loss after  6300  epochs :  27.17751912927589
# Loss after  6310  epochs :  27.163123770821937
# Loss after  6320  epochs :  27.148757323697588
# Loss after  6330  epochs :  27.134419662154883
# Loss after  6340  epochs :  27.12011066120256
# Loss after  6350  epochs :  27.105830196601143
# Loss after  6360  epochs :  27.091578144858058
# Loss after  6370  epochs :  27.077354383222783
# Loss after  6380  epochs :  27.063158789682035
# Loss after  6390  epochs :  27.04899124295498
# Loss after  6400  epochs :  27.034851622488485
# Loss after  6410  epochs :  27.020739808452383
# Loss after  6420  epochs :  27.006655681734802
# Loss after  6430  epochs :  26.99259912393749
# Loss after  6440  epochs :  26.978570017371197
# Loss after  6450  epochs :  26.96456824505105
# Loss after  6460  epochs :  26.950593690692003
# Loss after  6470  epochs :  26.936646238704324
# Loss after  6480  epochs :  26.922725774189036
# Loss after  6490  epochs :  26.908832182933462
# Loss after  6500  epochs :  26.894965351406785
# Loss after  6510  epochs :  26.88112516675562
# Loss after  6520  epochs :  26.867311516799614
# Loss after  6530  epochs :  26.853524290027092
# Loss after  6540  epochs :  26.839763375590724
# Loss after  6550  epochs :  26.82602866330323
# Loss after  6560  epochs :  26.812320043633065
# Loss after  6570  epochs :  26.798637407700237
# Loss after  6580  epochs :  26.78498064727202
# Loss after  6590  epochs :  26.771349654758808
# Loss after  6600  epochs :  26.75774432320992
# Loss after  6610  epochs :  26.744164546309474
# Loss after  6620  epochs :  26.7306102183723
# Loss after  6630  epochs :  26.71708123433981
# Loss after  6640  epochs :  26.703577489775995
# Loss after  6650  epochs :  26.69009888086333
# Loss after  6660  epochs :  26.676645304398853
# Loss after  6670  epochs :  26.663216657790116
# Loss after  6680  epochs :  26.64981283905128
# Loss after  6690  epochs :  26.63643374679917
# Loss after  6700  epochs :  26.623079280249375
# Loss after  6710  epochs :  26.609749339212396
# Loss after  6720  epochs :  26.59644382408978
# Loss after  6730  epochs :  26.58316263587029
# Loss after  6740  epochs :  26.569905676126165
# Loss after  6750  epochs :  26.556672847009253
# Loss after  6760  epochs :  26.543464051247355
# Loss after  6770  epochs :  26.530279192140448
# Loss after  6780  epochs :  26.51711817355701
# Loss after  6790  epochs :  26.503980899930337
# Loss after  6800  epochs :  26.490867276254914
# Loss after  6810  epochs :  26.477777208082763
# Loss after  6820  epochs :  26.464710601519858
# Loss after  6830  epochs :  26.451667363222544
# Loss after  6840  epochs :  26.438647400393975
# Loss after  6850  epochs :  26.425650620780612
# Loss after  6860  epochs :  26.41267693266868
# Loss after  6870  epochs :  26.399726244880718
# Loss after  6880  epochs :  26.38679846677207
# Loss after  6890  epochs :  26.3738935082275
# Loss after  6900  epochs :  26.361011279657763
# Loss after  6910  epochs :  26.348151691996183
# Loss after  6920  epochs :  26.3353146566953
# Loss after  8330  epochs :  24.716287892520793
# Loss after  8340  epochs :  24.70595764331496
# Loss after  8350  epochs :  24.69564129052684
# Loss after  8360  epochs :  24.68533879423084
# Loss after  8370  epochs :  24.675050114707016
# Loss after  8380  epochs :  24.664775212439757
# Loss after  8390  epochs :  24.65451404811653
# Loss after  8400  epochs :  24.64426658262658
# Loss after  8410  epochs :  24.634032777059698
# Loss after  8420  epochs :  24.62381259270493
# Loss after  8430  epochs :  24.613605991049376
# Loss after  8440  epochs :  24.60341293377691
# Loss after  8450  epochs :  24.593233382766982
# Loss after  8460  epochs :  24.583067300093372
# Loss after  8470  epochs :  24.57291464802298
# Loss after  8480  epochs :  24.562775389014643
# Loss after  8490  epochs :  24.55264948571791
# Loss after  8500  epochs :  24.54253690097185
# Loss after  8510  epochs :  24.532437597803895
# Loss after  8520  epochs :  24.52235153942865
# Loss after  8530  epochs :  24.512278689246724
# Loss after  8540  epochs :  24.50221901084356
# Loss after  8550  epochs :  24.492172467988325
# Loss after  8560  epochs :  24.482139024632705
# Loss after  8570  epochs :  24.472118644909816
# Loss after  8580  epochs :  24.462111293133052
# Loss after  8590  epochs :  24.452116933794983
# Loss after  8600  epochs :  24.4421355315662
# Loss after  8610  epochs :  24.432167051294257
# Loss after  8620  epochs :  24.42221145800254
# Loss after  8630  epochs :  24.412268716889184
# Loss after  8640  epochs :  24.402338793325963
# Loss after  8650  epochs :  24.392421652857266
# Loss after  8660  epochs :  24.382517261198977
# Loss after  8670  epochs :  24.37262558423741
# Loss after  8680  epochs :  24.36274658802829
# Loss after  8690  epochs :  24.35288023879567
# Loss after  8700  epochs :  24.343026502930883
# Loss after  8710  epochs :  24.33318534699153
# Loss after  8720  epochs :  24.32335673770044
# Loss after  8730  epochs :  24.31354064194462
# Loss after  8740  epochs :  24.303737026774293
# Loss after  8750  epochs :  24.293945859401834
# Loss after  8760  epochs :  24.28416710720079
# Loss after  8770  epochs :  24.274400737704884
# Loss after  8780  epochs :  24.264646718607015
# Loss after  8790  epochs :  24.25490501775829
# Loss after  8800  epochs :  24.24517560316702
# Loss after  8810  epochs :  24.235458442997775
# Loss after  8820  epochs :  24.225753505570403
# Loss after  8830  epochs :  24.216060759359078
# Loss after  8840  epochs :  24.20638017299135
# Loss after  8850  epochs :  24.19671171524718
# Loss after  8860  epochs :  24.187055355058025
# Loss after  8870  epochs :  24.177411061505893
# Loss after  8880  epochs :  24.167778803822404
# Loss after  8890  epochs :  24.1581585513879
# Loss after  8900  epochs :  24.14855027373048
# Loss after  8910  epochs :  24.13895394052513
# Loss after  8920  epochs :  24.12936952159282
# Loss after  8930  epochs :  24.119796986899583
# Loss after  8940  epochs :  24.11023630655562
# Loss after  8950  epochs :  24.100687450814444
# Loss after  8960  epochs :  24.091150390071977
# Loss after  8970  epochs :  24.081625094865675
# Loss after  8980  epochs :  24.07211153587366
# Loss after  8990  epochs :  24.062609683913877
# Loss after  9000  epochs :  24.053119509943198
# Loss after  9010  epochs :  24.043640985056605
# Loss after  9020  epochs :  24.034174080486324
# Loss after  9030  epochs :  24.024718767600987
# Loss after  9040  epochs :  24.015275017904806
# Loss after  9050  epochs :  24.005842803036714
# Loss after  9060  epochs :  23.996422094769585
# Loss after  9070  epochs :  23.98701286500938
# Loss after  9080  epochs :  23.977615085794344
# Loss after  9090  epochs :  23.96822872929419
# Loss after  9100  epochs :  23.958853767809305
# Loss after  9110  epochs :  23.949490173769952
# Loss after  9120  epochs :  23.94013791973547
# Loss after  9130  epochs :  23.930796978393477
# Loss after  9140  epochs :  23.921467322559124
# Loss after  9150  epochs :  23.912148925174268
# Loss after  9160  epochs :  23.90284175930674
# Loss after  9170  epochs :  23.893545798149542
# Loss after  9180  epochs :  23.88426101502012
# Loss after  9190  epochs :  23.87498738335959
# Loss after  9200  epochs :  23.86572487673196
# Loss after  9210  epochs :  23.85647346882343
# Loss after  9220  epochs :  23.847233133441623
# Loss after  9230  epochs :  23.838003844514834
# Loss after  9240  epochs :  23.828785576091327
# Loss after  9250  epochs :  23.819578302338574
# Loss after  9260  epochs :  23.810381997542564
# Loss after  9270  epochs :  23.801196636107058
# Loss after  9280  epochs :  23.79202219255289
# Loss after  9290  epochs :  23.78285864151725
# Loss after  9300  epochs :  23.773705957752963
# Loss after  9310  epochs :  23.764564116127843
# Loss after  9320  epochs :  23.755433091623917
# Loss after  9330  epochs :  23.746312859336786
# Loss after  9340  epochs :  23.737203394474946
# Loss after  9350  epochs :  23.728104672359073
# Loss after  9360  epochs :  23.719016668421354
# Loss after  9370  epochs :  23.709939358204828
# Loss after  9380  epochs :  23.700872717362696
# Loss after  9390  epochs :  23.691816721657666
# Loss after  9400  epochs :  23.682771346961307
# Loss after  9410  epochs :  23.673736569253343
# Loss after  9420  epochs :  23.664712364621074
# Loss after  9430  epochs :  23.65569870925867
# Loss after  9440  epochs :  23.64669557946654
# Loss after  9450  epochs :  23.637702951650713
# Loss after  9460  epochs :  23.628720802322174
# Loss after  9470  epochs :  23.619749108096265
# Loss after  9480  epochs :  23.61078784569202
# Loss after  9490  epochs :  23.601836991931577
# Loss after  9500  epochs :  23.59289652373952
# Loss after  9510  epochs :  23.583966418142314
# Loss after  9520  epochs :  23.575046652267655
# Loss after  9530  epochs :  23.566137203343875
# Loss after  9540  epochs :  23.55723804869933
# Loss after  9550  epochs :  23.548349165761827
# Loss after  9560  epochs :  23.53947053205799
# Loss after  9570  epochs :  23.530602125212702
# Loss after  9580  epochs :  23.521743922948506
# Loss after  9590  epochs :  23.512895903085003
# Loss after  9600  epochs :  23.504058043538308
# Loss after  9610  epochs :  23.49523032232044
# Loss after  9620  epochs :  23.486412717538776
# Loss after  9630  epochs :  23.477605207395445
# Loss after  9640  epochs :  23.468807770186814
# Loss after  9650  epochs :  23.460020384302876
# Loss after  9660  epochs :  23.451243028226735
# Loss after  9670  epochs :  23.442475680534013
# Loss after  9680  epochs :  23.433718319892343
# Loss after  9690  epochs :  23.424970925060766
# Loss after  9700  epochs :  23.41623347488923
# Loss after  9710  epochs :  23.407505948318054
# Loss after  9720  epochs :  23.39878832437735
# Loss after  9730  epochs :  23.390080582186535
# Loss after  9740  epochs :  23.38138270095376
# Loss after  9750  epochs :  23.37269465997542
# Loss after  9760  epochs :  23.36401643863562
# Loss after  9770  epochs :  23.355348016405642
# Loss after  9780  epochs :  23.346689372843432
# Loss after  9790  epochs :  23.33804048759311
# Loss after  9800  epochs :  23.329401340384425
# Loss after  9810  epochs :  23.32077191103229
# Loss after  9820  epochs :  23.312152179436236
# Loss after  9830  epochs :  23.303542125579945
# Loss after  9840  epochs :  23.294941729530727
# Loss after  9850  epochs :  23.286350971439063
# Loss after  9860  epochs :  23.27776983153808
# Loss after  9870  epochs :  23.269198290143073
# Loss after  9880  epochs :  23.26063632765103
# Loss after  9890  epochs :  23.252083924540152
# Loss after  9900  epochs :  23.243541061369356
# Loss after  9910  epochs :  23.235007718777833
# Loss after  9920  epochs :  23.226483877484547
# Loss after  9930  epochs :  23.217969518287774
# Loss after  9940  epochs :  23.20946462206465
# Loss after  9950  epochs :  23.20096916977069
# Loss after  9960  epochs :  23.192483142439347
# Loss after  9970  epochs :  23.18400652118154
# Loss after  9980  epochs :  23.175539287185213
# Loss after  9990  epochs :  23.167081421714865
# Updated w:  [[-1.75601664  4.39968808 -2.3113518   2.86323706 -1.45834668 12.31693518
#    2.67575803  1.99769697 -1.49309854 -1.30239756 -1.46069083  9.59564835
#   -4.25805938]]
# Updated b:  9.791594727952372

# %% [markdown]
# ### 1.5. Final Train Error and Test Error

# %% [markdown]
# After the linear regression model is trained, we will compute the final train error and test error for the trained model.

# %%
## Train and Test error computation
train_error = loss_function(X_train,y_train,w,b)
test_error = loss_function(X_test,y_test,w,b)
print("Train Error: ",train_error, " Test error: ", test_error)
# Out:
# Train Error:  23.158632906111126  Test error:  14.9732788654663

# %% [markdown]
# ### 1.6. Plotting the loss function

# %% [markdown]
# We will plot the loss function values for every training iteration. If the model is trained properly, you will see that the loss function reduces as the training progesses and it converges at some point.

# %%
# PLotting the loss values for every training iterations

loss_plot = [loss_hist[i][0][0] for i in range(len(loss_hist))]
plt.xlabel("Iterations")
plt.ylabel("Loss function")
plt.plot(loss_plot)
plt.show()

# %% [markdown]
# ### 1.7. Plotting the histogram of loss

# %%
def mse_losses(X, y, w, b):
    y_pred = np.dot(X, w.T) + b
    losses = (y_pred - y)**2
    return losses

# %%
import numpy as np
import matplotlib.pyplot as plt

loss_linear = mse_losses(X_test,y_test,w,b)
loss_linear = np.ravel(loss_linear)
# Plot histograms
plt.figure(figsize=(12, 6))

# Linear regression loss histogram
plt.subplot(1, 2, 1)
plt.hist(loss_linear, bins=20, color='blue', alpha=0.7, edgecolor='black')
plt.title('Loss Histogram: Linear Regression')
plt.xlabel('Squared Error Loss')
plt.ylabel('Frequency')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.8 Experimenting with different values of the Hyperparemeters
#
# Previously, we have took the learning rate as 0.001. Now, you have to train the model again by taking learning rate as-
#
#
# 1.   0.01
# 2.   0.001
#
#
# After the model is trained, you have to compare the performance of the model with these chosen hyperparameters.

# %%
## CODE REQUIRED ##

"""
Compare the performance with the chosen hyperparameters.
"""

### START CODE HERE ###
alpha_list = [0.01, 0.001]

for alpha in alpha_list:
    w,b,loss_hist = batch_gradient_descent(X_train ,y_train, initial_w, initial_b, alpha, num_iters)
    train_error = loss_function(X_train,y_train,w,b)
    test_error = loss_function(X_test,y_test,w,b)
    print(f"Train Error for learning_rate = {alpha} : ",train_error, f" Test error for learning_rate = {alpha} : ", test_error)


### END CODE HERE ###
# Out:
# Loss after  0  epochs :  282.04502069891436
# Loss after  10  epochs :  163.82862212368173
# Loss after  20  epochs :  107.43141809262761
# Loss after  30  epochs :  80.11744387873081
# Loss after  40  epochs :  66.50921786342244
# Loss after  50  epochs :  59.38180973008682
# Loss after  60  epochs :  55.33929469951418
# Loss after  70  epochs :  52.78420364741058
# Loss after  80  epochs :  50.96387127409762
# Loss after  90  epochs :  49.52254630383787
# Loss after  100  epochs :  48.29103168770168
# Loss after  110  epochs :  47.187880559496634
# Loss after  120  epochs :  46.17298454981216
# Loss after  130  epochs :  45.22576854390767
# Loss after  140  epochs :  44.33494229260987
# Loss after  150  epochs :  43.49368014901461
# Loss after  160  epochs :  42.69735056467761
# Loss after  170  epochs :  41.94244350131569
# Loss after  180  epochs :  41.226060841670474
# Loss after  190  epochs :  40.54567158745214
# Loss after  200  epochs :  39.89899176589469
# Loss after  210  epochs :  39.28392323489839
# Loss after  220  epochs :  38.69852045810125
# Loss after  230  epochs :  38.14097070449604
# Loss after  240  epochs :  37.60958082283268
# Loss after  250  epochs :  37.10276735646315
# Loss after  260  epochs :  36.61904846337276
# Loss after  270  epochs :  36.157036905157504
# Loss after  280  epochs :  35.715433744941656
# Loss after  290  epochs :  35.29302257184334
# Loss after  300  epochs :  34.88866415386797
# Loss after  310  epochs :  34.50129146149005
# Loss after  320  epochs :  34.12990502389842
# Loss after  330  epochs :  33.77356858984159
# Loss after  340  epochs :  33.43140507034441
# Loss after  350  epochs :  33.102592743687666
# Loss after  360  epochs :  32.78636170508284
# Loss after  370  epochs :  32.48199054497032
# Loss after  380  epochs :  32.188803241075675
# Loss after  390  epochs :  31.906166250395795
# Loss after  400  epochs :  31.633485788215076
# Loss after  410  epochs :  31.370205282099423
# Loss after  420  epochs :  31.115802989600258
# Loss after  430  epochs :  30.869789769129802
# Loss after  440  epochs :  30.631706994149077
# Loss after  450  epochs :  30.401124601445453
# Loss after  460  epochs :  30.177639264870642
# Loss after  470  epochs :  29.9608726864657
# Loss after  480  epochs :  29.750469997419184
# Loss after  490  epochs :  29.546098261791016
# Loss after  500  epochs :  29.3474450763894
# Loss after  510  epochs :  29.15421726061372
# Loss after  520  epochs :  28.966139630474856
# Loss after  530  epochs :  28.782953851376444
# Loss after  540  epochs :  28.604417364589736
# Loss after  550  epochs :  28.43030238268045
# Loss after  560  epochs :  28.26039494945151
# Loss after  570  epochs :  28.094494060250803
# Loss after  580  epochs :  27.93241083876048
# Loss after  590  epochs :  27.773967766634033
# Loss after  600  epochs :  27.618997962581584
# Loss after  610  epochs :  27.467344507722206
# Loss after  620  epochs :  27.31885981422714
# Loss after  630  epochs :  27.17340503446929
# Loss after  640  epochs :  27.030849508073352
# Loss after  650  epochs :  26.891070244429002
# Loss after  660  epochs :  26.753951438386075
# Loss after  670  epochs :  26.619384016997728
# Loss after  680  epochs :  26.487265215314782
# Loss after  690  epochs :  26.357498179363063
# Loss after  700  epochs :  26.229991594555624
# Loss after  710  epochs :  26.10465933790435
# Loss after  720  epochs :  25.98142015250074
# Loss after  730  epochs :  25.86019734283393
# Loss after  740  epochs :  25.740918489606468
# Loss after  750  epochs :  25.623515182794197
# Loss after  760  epochs :  25.507922771777668
# Loss after  770  epochs :  25.39408013144757
# Loss after  780  epochs :  25.281929443257564
# Loss after  790  epochs :  25.171415990263895
# Loss after  800  epochs :  25.062487965252902
# Loss after  810  epochs :  24.955096291115414
# Loss after  820  epochs :  24.849194452681253
# Loss after  830  epochs :  24.74473833927745
# Loss after  840  epochs :  24.641686097321415
# Loss after  850  epochs :  24.53999799230445
# Loss after  860  epochs :  24.43963627956247
# Loss after  870  epochs :  24.340565083269784
# Loss after  880  epochs :  24.24275028312779
# Loss after  890  epochs :  24.146159408254654
# Loss after  900  epochs :  24.05076153781376
# Loss after  910  epochs :  23.95652720794833
# Loss after  920  epochs :  23.863428324617676
# Loss after  930  epochs :  23.771438081956262
# Loss after  940  epochs :  23.68053088580147
# Loss after  950  epochs :  23.59068228205839
# Loss after  960  epochs :  23.50186888959158
# Loss after  970  epochs :  23.41406833735356
# Loss after  980  epochs :  23.32725920547828
# Loss after  990  epochs :  23.24142097008579
# Loss after  1000  epochs :  23.156533951560025
# Loss after  1010  epochs :  23.07257926607743
# Loss after  1020  epochs :  22.989538780178208
# Loss after  1030  epochs :  22.907395068185327
# Loss after  1040  epochs :  22.826131372289186
# Loss after  1050  epochs :  22.745731565127212
# Loss after  1060  epochs :  22.666180114698932
# Loss after  1070  epochs :  22.587462051467167
# Loss after  1080  epochs :  22.509562937505585
# Loss after  1090  epochs :  22.432468837561903
# Loss after  1100  epochs :  22.35616629191438
# Loss after  1110  epochs :  22.28064229090716
# Loss after  1120  epochs :  22.205884251057196
# Loss after  1130  epochs :  22.13187999263276
# Loss after  1140  epochs :  22.058617718609465
# Loss after  1150  epochs :  21.98608599491619
# Loss after  1160  epochs :  21.91427373188874
# Loss after  1170  epochs :  21.843170166854307
# Loss after  1180  epochs :  21.772764847774862
# Loss after  1190  epochs :  21.703047617882195
# Loss after  1200  epochs :  21.634008601241472
# Loss after  1210  epochs :  21.565638189184543
# Loss after  1220  epochs :  21.49792702755768
# Loss after  1230  epochs :  21.43086600473219
# Loss after  1240  epochs :  21.364446240329638
# Loss after  1250  epochs :  21.298659074616328
# Loss after  1260  epochs :  21.233496058524825
# Loss after  1270  epochs :  21.16894894426293
# Loss after  1280  epochs :  21.10500967647295
# Loss after  1290  epochs :  21.041670383906684
# Loss after  1300  epochs :  20.978923371583548
# Loss after  1310  epochs :  20.91676111340155
# Loss after  1320  epochs :  20.855176245172597
# Loss after  1330  epochs :  20.7941615580556
# Loss after  1340  epochs :  20.73370999236233
# Loss after  1350  epochs :  20.673814631712858
# Loss after  1360  epochs :  20.61446869751862
# Loss after  1370  epochs :  20.555665543772747
# Loss after  1380  epochs :  20.497398652128492
# Loss after  1390  epochs :  20.439661627247904
# Loss after  1400  epochs :  20.38244819240389
# Loss after  1410  epochs :  20.325752185320045
# Loss after  1420  epochs :  20.269567554233614
# Loss after  1430  epochs :  20.213888354167644
# Loss after  1440  epochs :  20.158708743399643
# Loss after  1450  epochs :  20.104022980114618
# Loss after  1460  epochs :  20.04982541923114
# Loss after  1470  epochs :  19.996110509390018
# Loss after  1480  epochs :  19.942872790095468
# Loss after  1490  epochs :  19.890106888999743
# Loss after  1500  epochs :  19.837807519322403
# Loss after  1510  epochs :  19.785969477396083
# Loss after  1520  epochs :  19.73458764033124
# Loss after  1530  epochs :  19.683656963792696
# Loss after  1540  epochs :  19.633172479881264
# Loss after  1550  epochs :  19.58312929511429
# Loss after  1560  epochs :  19.53352258849918
# Loss after  1570  epochs :  19.48434760969444
# Loss after  1580  epochs :  19.43559967725307
# Loss after  1590  epochs :  19.387274176943542
# Loss after  1600  epochs :  19.339366560143844
# Loss after  1610  epochs :  19.291872342304238
# Loss after  1620  epochs :  19.244787101474945
# Loss after  1630  epochs :  19.198106476894903
# Loss after  1640  epochs :  19.151826167638234
# Loss after  1650  epochs :  19.10594193131496
# Loss after  1660  epochs :  19.06044958282317
# Loss after  1670  epochs :  19.01534499314955
# Loss after  1680  epochs :  18.970624088215672
# Loss after  1690  epochs :  18.926282847767517
# Loss after  1700  epochs :  18.88231730430586
# Loss after  1710  epochs :  18.83872354205528
# Loss after  1720  epochs :  18.795497695969747
# Loss after  1730  epochs :  18.75263595077275
# Loss after  1740  epochs :  18.71013454003026
# Loss after  1750  epochs :  18.667989745254687
# Loss after  1760  epochs :  18.626197895038253
# Loss after  1770  epochs :  18.584755364214303
# Loss after  1780  epochs :  18.54365857304509
# Loss after  1790  epochs :  18.50290398643468
# Loss after  1800  epochs :  18.462488113165758
# Loss after  1810  epochs :  18.422407505159107
# Loss after  1820  epochs :  18.382658756754758
# Loss after  1830  epochs :  18.343238504013577
# Loss after  1840  epochs :  18.30414342403851
# Loss after  1850  epochs :  18.265370234314414
# Loss after  1860  epochs :  18.22691569206571
# Loss after  1870  epochs :  18.18877659363096
# Loss after  1880  epochs :  18.15094977385363
# Loss after  1890  epochs :  18.113432105488364
# Loss after  1900  epochs :  18.076220498622
# Loss after  1910  epochs :  18.039311900108743
# Loss after  1920  epochs :  18.00270329301887
# Loss after  1930  epochs :  17.966391696100438
# Loss after  1940  epochs :  17.93037416325336
# Loss after  1950  epochs :  17.89464778301548
# Loss after  1960  epochs :  17.85920967806
# Loss after  1970  epochs :  17.824057004704013
# Loss after  1980  epochs :  17.789186952427514
# Loss after  1990  epochs :  17.7545967434026
# Loss after  2000  epochs :  17.7202836320325
# Loss after  2010  epochs :  17.686244904499944
# Loss after  2020  epochs :  17.652477878324696
# Loss after  2030  epochs :  17.618979901929794
# Loss after  2040  epochs :  17.585748354216296
# Loss after  2050  epochs :  17.552780644146154
# Loss after  2060  epochs :  17.520074210332965
# Loss after  2070  epochs :  17.48762652064044
# Loss after  2080  epochs :  17.455435071788177
# Loss after  2090  epochs :  17.423497388964602
# Loss after  2100  epochs :  17.391811025446916
# Loss after  2110  epochs :  17.360373562227647
# Loss after  2120  epochs :  17.32918260764783
# Loss after  2130  epochs :  17.298235797036433
# Loss after  2140  epochs :  17.267530792355995
# Loss after  2150  epochs :  17.23706528185421
# Loss after  2160  epochs :  17.20683697972132
# Loss after  2170  epochs :  17.176843625753158
# Loss after  2180  epochs :  17.14708298501972
# Loss after  2190  epochs :  17.117552847539066
# Loss after  2200  epochs :  17.088251027956478
# Loss after  2210  epochs :  17.05917536522864
# Loss after  2220  epochs :  17.03032372231291
# Loss after  2230  epochs :  17.001693985861273
# Loss after  2240  epochs :  16.973284065919184
# Loss after  2250  epochs :  16.945091895628927
# Loss after  2260  epochs :  16.917115430937532
# Loss after  2270  epochs :  16.889352650309085
# Loss after  2280  epochs :  16.861801554441392
# Loss after  2290  epochs :  16.834460165986822
# Loss after  2300  epochs :  16.807326529277304
# Loss after  2310  epochs :  16.78039871005334
# Loss after  2320  epochs :  16.753674795197064
# Loss after  2330  epochs :  16.72715289246905
# Loss after  2340  epochs :  16.700831130249036
# Loss after  2350  epochs :  16.67470765728032
# Loss after  2360  epochs :  16.648780642417815
# Loss after  2370  epochs :  16.623048274379727
# Loss after  2380  epochs :  16.59750876150266
# Loss after  2390  epochs :  16.572160331500296
# Loss after  2400  epochs :  16.547001231225344
# Loss after  2410  epochs :  16.522029726434898
# Loss after  2420  epochs :  16.497244101559005
# Loss after  2430  epochs :  16.472642659472484
# Loss after  2440  epochs :  16.448223721269862
# Loss after  2450  epochs :  16.423985626043407
# Loss after  2460  epochs :  16.399926730664255
# Loss after  2470  epochs :  16.376045409566437
# Loss after  2480  epochs :  16.352340054533936
# Loss after  2490  epochs :  16.328809074490593
# Loss after  2500  epochs :  16.30545089529284
# Loss after  2510  epochs :  16.282263959525267
# Loss after  2520  epochs :  16.259246726298922
# Loss after  2530  epochs :  16.23639767105233
# Loss after  2540  epochs :  16.213715285355153
# Loss after  2550  epochs :  16.191198076714493
# Loss after  2560  epochs :  16.168844568383772
# Loss after  2570  epochs :  16.146653299174154
# Loss after  2580  epochs :  16.124622823268453
# Loss after  2590  epochs :  16.10275171003752
# Loss after  2600  epochs :  16.081038543859066
# Loss after  2610  epochs :  16.05948192393883
# Loss after  2620  epochs :  16.038080464134158
# Loss after  2630  epochs :  16.016832792779837
# Loss after  2640  epochs :  15.995737552516273
# Loss after  2650  epochs :  15.97479340011986
# Loss after  2660  epochs :  15.953999006335625
# Loss after  2670  epochs :  15.933353055711981
# Loss after  2680  epochs :  15.912854246437707
# Loss after  2690  epochs :  15.892501290180995
# Loss after  2700  epochs :  15.872292911930609
# Loss after  2710  epochs :  15.852227849839105
# Loss after  2720  epochs :  15.832304855068047
# Loss after  2730  epochs :  15.812522691635287
# Loss after  2740  epochs :  15.792880136264133
# Loss after  2750  epochs :  15.773375978234549
# Loss after  2760  epochs :  15.754009019236188
# Loss after  2770  epochs :  15.734778073223389
# Loss after  2780  epochs :  15.715681966271953
# Loss after  2790  epochs :  15.696719536437866
# Loss after  2800  epochs :  15.677889633617712
# Loss after  2810  epochs :  15.659191119410943
# Loss after  2820  epochs :  15.64062286698391
# Loss after  2830  epochs :  15.622183760935583
# Loss after  2840  epochs :  15.603872697165052
# Loss after  2850  epochs :  15.585688582740637
# Loss after  2860  epochs :  15.567630335770723
# Loss after  2870  epochs :  15.549696885276212
# Loss after  2880  epochs :  15.53188717106461
# Loss after  2890  epochs :  15.514200143605674
# Loss after  2900  epochs :  15.496634763908672
# Loss after  2910  epochs :  15.479190003401195
# Loss after  2920  epochs :  15.46186484380947
# Loss after  2930  epochs :  15.444658277040233
# Loss after  2940  epochs :  15.42756930506403
# Loss after  2950  epochs :  15.410596939800042
# Loss after  2960  epochs :  15.393740203002354
# Loss after  2970  epochs :  15.37699812614763
# Loss after  2980  epochs :  15.360369750324217
# Loss after  2990  epochs :  15.34385412612263
# Loss after  3000  epochs :  15.327450313527455
# Loss after  3010  epochs :  15.311157381810514
# Loss after  3020  epochs :  15.294974409425489
# Loss after  3030  epochs :  15.278900483903767
# Loss after  3040  epochs :  15.262934701751622
# Loss after  3050  epochs :  15.2470761683487
# Loss after  3060  epochs :  15.231323997847753
# Loss after  3070  epochs :  15.215677313075599
# Loss after  3080  epochs :  15.200135245435373
# Loss after  3090  epochs :  15.184696934809944
# Loss after  3100  epochs :  15.169361529466547
# Loss after  3110  epochs :  15.154128185962625
# Loss after  3120  epochs :  15.138996069052807
# Loss after  3130  epochs :  15.123964351597051
# Loss after  3140  epochs :  15.109032214469943
# Loss after  3150  epochs :  15.09419884647108
# Loss after  3160  epochs :  15.079463444236609
# Loss after  3170  epochs :  15.064825212151822
# Loss after  3180  epochs :  15.050283362264844
# Loss after  3190  epochs :  15.035837114201394
# Loss after  3200  epochs :  15.021485695080598
# Loss after  3210  epochs :  15.007228339431808
# Loss after  3220  epochs :  14.993064289112478
# Loss after  3230  epochs :  14.978992793227059
# Loss after  3240  epochs :  14.965013108046838
# Loss after  3250  epochs :  14.951124496930822
# Loss after  3260  epochs :  14.937326230247546
# Loss after  3270  epochs :  14.92361758529787
# Loss after  3280  epochs :  14.909997846238701
# Loss after  3290  epochs :  14.896466304007667
# Loss after  3300  epochs :  14.883022256248708
# Loss after  3310  epochs :  14.869665007238527
# Loss after  3320  epochs :  14.856393867814038
# Loss after  3330  epochs :  14.8432081553006
# Loss after  3340  epochs :  14.830107193441178
# Loss after  3350  epochs :  14.81709031232637
# Loss after  3360  epochs :  14.80415684832525
# Loss after  3370  epochs :  14.791306144017065
# Loss after  3380  epochs :  14.778537548123792
# Loss after  3390  epochs :  14.765850415443454
# Loss after  3400  epochs :  14.753244106784319
# Loss after  3410  epochs :  14.740717988899812
# Loss after  3420  epochs :  14.728271434424279
# Loss after  3430  epochs :  14.71590382180949
# Loss after  3440  epochs :  14.703614535261947
# Loss after  3450  epochs :  14.691402964680897
# Loss after  3460  epochs :  14.679268505597125
# Loss after  3470  epochs :  14.667210559112494
# Loss after  3480  epochs :  14.655228531840159
# Loss after  3490  epochs :  14.643321835845583
# Loss after  3500  epochs :  14.631489888588188
# Loss after  3510  epochs :  14.619732112863714
# Loss after  3520  epochs :  14.60804793674733
# Loss after  3530  epochs :  14.59643679353735
# Loss after  3540  epochs :  14.584898121699673
# Loss after  3550  epochs :  14.573431364812855
# Loss after  3560  epochs :  14.562035971513852
# Loss after  3570  epochs :  14.550711395444432
# Loss after  3580  epochs :  14.539457095198172
# Loss after  3590  epochs :  14.528272534268133
# Loss after  3600  epochs :  14.517157180995145
# Loss after  3610  epochs :  14.506110508516683
# Loss after  3620  epochs :  14.495131994716388
# Loss after  3630  epochs :  14.484221122174167
# Loss after  3640  epochs :  14.473377378116881
# Loss after  3650  epochs :  14.462600254369606
# Loss after  3660  epochs :  14.451889247307525
# Loss after  3670  epochs :  14.441243857808299
# Loss after  3680  epochs :  14.430663591205084
# Loss after  3690  epochs :  14.420147957240056
# Loss after  3700  epochs :  14.40969647001851
# Loss after  3710  epochs :  14.39930864796345
# Loss after  3720  epochs :  14.388984013770788
# Loss after  3730  epochs :  14.37872209436499
# Loss after  3740  epochs :  14.368522420855323
# Loss after  3750  epochs :  14.358384528492529
# Loss after  3760  epochs :  14.34830795662608
# Loss after  3770  epochs :  14.338292248661883
# Loss after  3780  epochs :  14.328336952020527
# Loss after  3790  epochs :  14.31844161809594
# Loss after  3800  epochs :  14.308605802214638
# Loss after  3810  epochs :  14.298829063595342
# Loss after  3820  epochs :  14.289110965309122
# Loss after  3830  epochs :  14.279451074240011
# Loss after  3840  epochs :  14.269848961046039
# Loss after  3850  epochs :  14.260304200120745
# Loss after  3860  epochs :  14.250816369555125
# Loss after  3870  epochs :  14.241385051100037
# Loss after  3880  epochs :  14.232009830129016
# Loss after  3890  epochs :  14.222690295601526
# Loss after  3900  epochs :  14.21342604002666
# Loss after  3910  epochs :  14.204216659427216
# Loss after  3920  epochs :  14.195061753304225
# Loss after  3930  epochs :  14.185960924601874
# Loss after  3940  epochs :  14.17691377967282
# Loss after  3950  epochs :  14.167919928243908
# Loss after  3960  epochs :  14.158978983382305
# Loss after  3970  epochs :  14.150090561461976
# Loss after  3980  epochs :  14.141254282130605
# Loss after  3990  epochs :  14.132469768276831
# Loss after  4000  epochs :  14.123736645997894
# Loss after  4010  epochs :  14.11505454456765
# Loss after  4020  epochs :  14.106423096404932
# Loss after  4030  epochs :  14.09784193704229
# Loss after  4040  epochs :  14.089310705095071
# Loss after  4050  epochs :  14.080829042230869
# Loss after  4060  epochs :  14.072396593139304
# Loss after  4070  epochs :  14.064013005502131
# Loss after  4080  epochs :  14.055677929963737
# Loss after  4090  epochs :  14.047391020101921
# Loss after  4100  epochs :  14.039151932399012
# Loss after  4110  epochs :  14.030960326213359
# Loss after  4120  epochs :  14.022815863751076
# Loss after  4130  epochs :  14.014718210038122
# Loss after  4140  epochs :  14.006667032892755
# Loss after  4150  epochs :  13.998662002898222
# Loss after  4160  epochs :  13.990702793375753
# Loss after  4170  epochs :  13.982789080357948
# Loss after  4180  epochs :  13.97492054256235
# Loss after  4190  epochs :  13.96709686136538
# Loss after  4200  epochs :  13.959317720776543
# Loss after  4210  epochs :  13.951582807412928
# Loss after  4220  epochs :  13.943891810473986
# Loss after  4230  epochs :  13.936244421716586
# Loss after  4240  epochs :  13.928640335430366
# Loss after  4250  epochs :  13.921079248413319
# Loss after  4260  epochs :  13.913560859947706
# Loss after  4270  epochs :  13.90608487177619
# Loss after  4280  epochs :  13.898650988078234
# Loss after  4290  epochs :  13.891258915446796
# Loss after  4300  epochs :  13.883908362865249
# Loss after  4310  epochs :  13.876599041684566
# Loss after  4320  epochs :  13.86933066560075
# Loss after  4330  epochs :  13.86210295063253
# Loss after  4340  epochs :  13.854915615099275
# Loss after  4350  epochs :  13.847768379599165
# Loss after  4360  epochs :  13.840660966987617
# Loss after  4370  epochs :  13.833593102355909
# Loss after  4380  epochs :  13.82656451301007
# Loss after  4390  epochs :  13.819574928449983
# Loss after  4400  epochs :  13.812624080348721
# Loss after  4410  epochs :  13.805711702532118
# Loss after  4420  epochs :  13.798837530958531
# Loss after  4430  epochs :  13.792001303698877
# Loss after  4440  epochs :  13.785202760916816
# Loss after  4450  epochs :  13.778441644849202
# Loss after  4460  epochs :  13.771717699786725
# Loss after  4470  epochs :  13.765030672054786
# Loss after  4480  epochs :  13.758380309994505
# Loss after  4490  epochs :  13.75176636394405
# Loss after  4500  epochs :  13.745188586220051
# Loss after  4510  epochs :  13.73864673109929
# Loss after  4520  epochs :  13.732140554800582
# Loss after  4530  epochs :  13.72566981546678
# Loss after  4540  epochs :  13.719234273147075
# Loss after  4550  epochs :  13.71283368977939
# Loss after  4560  epochs :  13.706467829173057
# Loss after  4570  epochs :  13.70013645699158
# Loss after  4580  epochs :  13.69383934073565
# Loss after  4590  epochs :  13.687576249726332
# Loss after  4600  epochs :  13.681346955088397
# Loss after  4610  epochs :  13.67515122973386
# Loss after  4620  epochs :  13.668988848345696
# Loss after  4630  epochs :  13.662859587361694
# Loss after  4640  epochs :  13.656763224958532
# Loss after  4650  epochs :  13.650699541035978
# Loss after  4660  epochs :  13.644668317201258
# Loss after  4670  epochs :  13.63866933675365
# Loss after  4680  epochs :  13.632702384669125
# Loss after  4690  epochs :  13.626767247585283
# Loss after  4700  epochs :  13.62086371378634
# Loss after  4710  epochs :  13.61499157318832
# Loss after  4720  epochs :  13.609150617324415
# Loss after  4730  epochs :  13.603340639330439
# Loss after  4740  epochs :  13.597561433930531
# Loss after  4750  epochs :  13.591812797422877
# Loss after  4760  epochs :  13.586094527665718
# Loss after  4770  epochs :  13.580406424063389
# Loss after  4780  epochs :  13.574748287552577
# Loss after  4790  epochs :  13.569119920588696
# Loss after  4800  epochs :  13.563521127132379
# Loss after  4810  epochs :  13.557951712636159
# Loss after  4820  epochs :  13.552411484031254
# Loss after  4830  epochs :  13.546900249714477
# Loss after  4840  epochs :  13.541417819535331
# Loss after  4850  epochs :  13.535964004783171
# Loss after  4860  epochs :  13.530538618174564
# Loss after  4870  epochs :  13.525141473840728
# Loss after  4880  epochs :  13.519772387315104
# Loss after  4890  epochs :  13.514431175521104
# Loss after  4900  epochs :  13.509117656759908
# Loss after  4910  epochs :  13.503831650698462
# Loss after  4920  epochs :  13.498572978357542
# Loss after  4930  epochs :  13.49334146209995
# Loss after  4940  epochs :  13.488136925618868
# Loss after  4950  epochs :  13.482959193926275
# Loss after  4960  epochs :  13.47780809334152
# Loss after  4970  epochs :  13.472683451479991
# Loss after  4980  epochs :  13.467585097241916
# Loss after  4990  epochs :  13.462512860801242
# Loss after  5000  epochs :  13.457466573594681
# Loss after  5010  epochs :  13.452446068310817
# Loss after  5020  epochs :  13.447451178879332
# Loss after  5030  epochs :  13.44248174046037
# Loss after  5040  epochs :  13.437537589433964
# Loss after  5050  epochs :  13.432618563389608
# Loss after  5060  epochs :  13.427724501115907
# Loss after  5070  epochs :  13.422855242590332
# Loss after  5080  epochs :  13.418010628969103
# Loss after  5090  epochs :  13.41319050257712
# Loss after  5100  epochs :  13.408394706898063
# Loss after  5110  epochs :  13.403623086564531
# Loss after  5120  epochs :  13.398875487348306
# Loss after  5130  epochs :  13.394151756150716
# Loss after  5140  epochs :  13.389451740993078
# Loss after  5150  epochs :  13.384775291007243
# Loss after  5160  epochs :  13.380122256426233
# Loss after  5170  epochs :  13.375492488574983
# Loss after  5180  epochs :  13.370885839861142
# Loss after  5190  epochs :  13.366302163766004
# Loss after  5200  epochs :  13.361741314835491
# Loss after  5210  epochs :  13.357203148671251
# Loss after  5220  epochs :  13.352687521921824
# Loss after  5230  epochs :  13.348194292273913
# Loss after  5240  epochs :  13.343723318443722
# Loss after  5250  epochs :  13.339274460168385
# Loss after  5260  epochs :  13.334847578197483
# Loss after  5270  epochs :  13.330442534284645
# Loss after  5280  epochs :  13.326059191179201
# Loss after  5290  epochs :  13.321697412617963
# Loss after  5300  epochs :  13.317357063317052
# Loss after  5310  epochs :  13.313038008963815
# Loss after  5320  epochs :  13.308740116208806
# Loss after  5330  epochs :  13.304463252657868
# Loss after  5340  epochs :  13.300207286864277
# Loss after  5350  epochs :  13.295972088320966
# Loss after  5360  epochs :  13.291757527452798
# Loss after  5370  epochs :  13.287563475608968
# Loss after  5380  epochs :  13.28338980505542
# Loss after  5390  epochs :  13.279236388967359
# Loss after  5400  epochs :  13.275103101421854
# Loss after  5410  epochs :  13.270989817390483
# Loss after  5420  epochs :  13.26689641273206
# Loss after  5430  epochs :  13.262822764185405
# Loss after  5440  epochs :  13.258768749362249
# Loss after  5450  epochs :  13.254734246740124
# Loss after  5460  epochs :  13.250719135655388
# Loss after  5470  epochs :  13.246723296296253
# Loss after  5480  epochs :  13.242746609695946
# Loss after  5490  epochs :  13.238788957725877
# Loss after  5500  epochs :  13.234850223088904
# Loss after  5510  epochs :  13.230930289312647
# Loss after  5520  epochs :  13.227029040742869
# Loss after  5530  epochs :  13.223146362536921
# Loss after  5540  epochs :  13.219282140657237
# Loss after  5550  epochs :  13.215436261864914
# Loss after  5560  epochs :  13.211608613713313
# Loss after  5570  epochs :  13.207799084541755
# Loss after  5580  epochs :  13.204007563469265
# Loss after  5590  epochs :  13.200233940388364
# Loss after  5600  epochs :  13.196478105958931
# Loss after  5610  epochs :  13.1927399516021
# Loss after  5620  epochs :  13.18901936949426
# Loss after  5630  epochs :  13.185316252561032
# Loss after  5640  epochs :  13.181630494471408
# Loss after  5650  epochs :  13.177961989631838
# Loss after  5660  epochs :  13.17431063318042
# Loss after  5670  epochs :  13.17067632098118
# Loss after  5680  epochs :  13.167058949618312
# Loss after  5690  epochs :  13.16345841639056
# Loss after  5700  epochs :  13.1598746193056
# Loss after  5710  epochs :  13.156307457074494
# Loss after  5720  epochs :  13.152756829106176
# Loss after  5730  epochs :  13.149222635502012
# Loss after  5740  epochs :  13.145704777050392
# Loss after  5750  epochs :  13.142203155221372
# Loss after  5760  epochs :  13.138717672161377
# Loss after  5770  epochs :  13.135248230687937
# Loss after  5780  epochs :  13.131794734284469
# Loss after  5790  epochs :  13.128357087095129
# Loss after  5800  epochs :  13.124935193919686
# Loss after  5810  epochs :  13.121528960208442
# Loss after  5820  epochs :  13.118138292057225
# Loss after  5830  epochs :  13.114763096202383
# Loss after  5840  epochs :  13.111403280015873
# Loss after  5850  epochs :  13.10805875150035
# Loss after  5860  epochs :  13.104729419284316
# Loss after  5870  epochs :  13.101415192617333
# Loss after  5880  epochs :  13.09811598136523
# Loss after  5890  epochs :  13.09483169600541
# Loss after  5900  epochs :  13.09156224762215
# Loss after  5910  epochs :  13.088307547901964
# Loss after  5920  epochs :  13.085067509129019
# Loss after  5930  epochs :  13.081842044180581
# Loss after  5940  epochs :  13.078631066522455
# Loss after  5950  epochs :  13.075434490204563
# Loss after  5960  epochs :  13.07225222985647
# Loss after  5970  epochs :  13.069084200683005
# Loss after  5980  epochs :  13.06593031845988
# Loss after  5990  epochs :  13.06279049952939
# Loss after  6000  epochs :  13.059664660796102
# Loss after  6010  epochs :  13.05655271972263
# Loss after  6020  epochs :  13.053454594325414
# Loss after  6030  epochs :  13.050370203170546
# Loss after  6040  epochs :  13.047299465369631
# Loss after  6050  epochs :  13.044242300575688
# Loss after  6060  epochs :  13.041198628979076
# Loss after  6070  epochs :  13.038168371303472
# Loss after  6080  epochs :  13.035151448801871
# Loss after  6090  epochs :  13.032147783252617
# Loss after  6100  epochs :  13.029157296955482
# Loss after  6110  epochs :  13.02617991272777
# Loss after  6120  epochs :  13.023215553900448
# Loss after  6130  epochs :  13.020264144314325
# Loss after  6140  epochs :  13.017325608316263
# Loss after  6150  epochs :  13.014399870755389
# Loss after  6160  epochs :  13.011486856979399
# Loss after  6170  epochs :  13.008586492830828
# Loss after  6180  epochs :  13.005698704643393
# Loss after  6190  epochs :  13.002823419238366
# Loss after  6200  epochs :  12.999960563920958
# Loss after  6210  epochs :  12.997110066476731
# Loss after  7620  epochs :  12.69122168477496
# Loss after  7630  epochs :  12.689576409952481
# Loss after  7640  epochs :  12.68793676113896
# Loss after  7650  epochs :  12.686302709257216
# Loss after  7660  epochs :  12.684674225405544
# Loss after  7670  epochs :  12.683051280856567
# Loss after  7680  epochs :  12.681433847056105
# Loss after  7690  epochs :  12.67982189562202
# Loss after  7700  epochs :  12.678215398343113
# Loss after  7710  epochs :  12.676614327177997
# Loss after  7720  epochs :  12.675018654253977
# Loss after  7730  epochs :  12.673428351865974
# Loss after  7740  epochs :  12.671843392475408
# Loss after  7750  epochs :  12.670263748709118
# Loss after  7760  epochs :  12.668689393358298
# Loss after  7770  epochs :  12.6671202993774
# Loss after  7780  epochs :  12.665556439883096
# Loss after  7790  epochs :  12.663997788153207
# Loss after  7800  epochs :  12.662444317625663
# Loss after  7810  epochs :  12.660896001897461
# Loss after  7820  epochs :  12.659352814723627
# Loss after  7830  epochs :  12.657814730016197
# Loss after  7840  epochs :  12.656281721843191
# Loss after  7850  epochs :  12.654753764427609
# Loss after  7860  epochs :  12.653230832146422
# Loss after  7870  epochs :  12.651712899529572
# Loss after  7880  epochs :  12.65019994125899
# Loss after  7890  epochs :  12.64869193216761
# Loss after  7900  epochs :  12.64718884723838
# Loss after  7910  epochs :  12.645690661603311
# Loss after  7920  epochs :  12.644197350542504
# Loss after  7930  epochs :  12.642708889483194
# Loss after  7940  epochs :  12.641225253998803
# Loss after  7950  epochs :  12.639746419808
# Loss after  7960  epochs :  12.638272362773755
# Loss after  7970  epochs :  12.63680305890242
# Loss after  7980  epochs :  12.635338484342792
# Loss after  7990  epochs :  12.633878615385223
# Loss after  8000  epochs :  12.632423428460676
# Loss after  8010  epochs :  12.630972900139843
# Loss after  8020  epochs :  12.62952700713224
# Loss after  8030  epochs :  12.628085726285313
# Loss after  8040  epochs :  12.62664903458357
# Loss after  8050  epochs :  12.62521690914767
# Loss after  8060  epochs :  12.623789327233574
# Loss after  8070  epochs :  12.622366266231676
# Loss after  8080  epochs :  12.620947703665932
# Loss after  8090  epochs :  12.619533617193017
# Loss after  8100  epochs :  12.618123984601459
# Loss after  8110  epochs :  12.61671878381081
# Loss after  8120  epochs :  12.61531799287081
# Loss after  8130  epochs :  12.613921589960537
# Loss after  8140  epochs :  12.612529553387605
# Loss after  8150  epochs :  12.611141861587322
# Loss after  8160  epochs :  12.60975849312189
# Loss after  8170  epochs :  12.608379426679587
# Loss after  8180  epochs :  12.607004641073978
# Loss after  8190  epochs :  12.605634115243088
# Loss after  8200  epochs :  12.604267828248643
# Loss after  8210  epochs :  12.602905759275252
# Loss after  8220  epochs :  12.601547887629657
# Loss after  8230  epochs :  12.600194192739924
# Loss after  8240  epochs :  12.598844654154702
# Loss after  8250  epochs :  12.597499251542432
# Loss after  8260  epochs :  12.596157964690601
# Loss after  8270  epochs :  12.594820773504978
# Loss after  8280  epochs :  12.593487658008875
# Loss after  8290  epochs :  12.592158598342394
# Loss after  8300  epochs :  12.590833574761682
# Loss after  8310  epochs :  12.589512567638208
# Loss after  8320  epochs :  12.588195557458018
# Loss after  8330  epochs :  12.586882524821034
# Loss after  8340  epochs :  12.5855734504403
# Loss after  8350  epochs :  12.584268315141292
# Loss after  8360  epochs :  12.582967099861209
# Loss after  8370  epochs :  12.581669785648243
# Loss after  8380  epochs :  12.580376353660908
# Loss after  8390  epochs :  12.579086785167314
# Loss after  8400  epochs :  12.57780106154451
# Loss after  8410  epochs :  12.576519164277762
# Loss after  8420  epochs :  12.575241074959896
# Loss after  8430  epochs :  12.57396677529061
# Loss after  8440  epochs :  12.572696247075795
# Loss after  8450  epochs :  12.571429472226889
# Loss after  8460  epochs :  12.570166432760185
# Loss after  8470  epochs :  12.568907110796191
# Loss after  8480  epochs :  12.567651488558969
# Loss after  8490  epochs :  12.566399548375479
# Loss after  8500  epochs :  12.565151272674942
# Loss after  8510  epochs :  12.563906643988194
# Loss after  8520  epochs :  12.56266564494705
# Loss after  8530  epochs :  12.56142825828366
# Loss after  8540  epochs :  12.560194466829905
# Loss after  8550  epochs :  12.558964253516736
# Loss after  8560  epochs :  12.55773760137359
# Loss after  8570  epochs :  12.556514493527752
# Loss after  8580  epochs :  12.55529491320374
# Loss after  8590  epochs :  12.554078843722712
# Loss after  8600  epochs :  12.552866268501853
# Loss after  8610  epochs :  12.551657171053774
# Loss after  8620  epochs :  12.55045153498592
# Loss after  8630  epochs :  12.549249343999964
# Loss after  8640  epochs :  12.548050581891244
# Loss after  8650  epochs :  12.546855232548161
# Loss after  8660  epochs :  12.545663279951599
# Loss after  8670  epochs :  12.544474708174343
# Loss after  8680  epochs :  12.543289501380539
# Loss after  8690  epochs :  12.542107643825068
# Loss after  8700  epochs :  12.54092911985304
# Loss after  8710  epochs :  12.539753913899194
# Loss after  8720  epochs :  12.538582010487348
# Loss after  8730  epochs :  12.537413394229864
# Loss after  8740  epochs :  12.536248049827064
# Loss after  8750  epochs :  12.535085962066717
# Loss after  8760  epochs :  12.53392711582347
# Loss after  8770  epochs :  12.532771496058325
# Loss after  8780  epochs :  12.531619087818099
# Loss after  8790  epochs :  12.530469876234879
# Loss after  8800  epochs :  12.529323846525521
# Loss after  8810  epochs :  12.528180983991088
# Loss after  8820  epochs :  12.527041274016364
# Loss after  8830  epochs :  12.525904702069312
# Loss after  8840  epochs :  12.524771253700562
# Loss after  8850  epochs :  12.523640914542908
# Loss after  8860  epochs :  12.522513670310795
# Loss after  8870  epochs :  12.521389506799816
# Loss after  8880  epochs :  12.5202684098862
# Loss after  8890  epochs :  12.519150365526327
# Loss after  8900  epochs :  12.518035359756233
# Loss after  8910  epochs :  12.516923378691104
# Loss after  8920  epochs :  12.515814408524795
# Loss after  8930  epochs :  12.514708435529357
# Loss after  8940  epochs :  12.513605446054534
# Loss after  8950  epochs :  12.512505426527296
# Loss after  8960  epochs :  12.51140836345136
# Loss after  8970  epochs :  12.510314243406723
# Loss after  8980  epochs :  12.509223053049173
# Loss after  8990  epochs :  12.508134779109854
# Loss after  9000  epochs :  12.507049408394773
# Loss after  9010  epochs :  12.505966927784353
# Loss after  9020  epochs :  12.504887324232977
# Loss after  9030  epochs :  12.503810584768527
# Loss after  9040  epochs :  12.502736696491935
# Loss after  9050  epochs :  12.501665646576733
# Loss after  9060  epochs :  12.500597422268614
# Loss after  9070  epochs :  12.49953201088498
# Loss after  9080  epochs :  12.49846939981451
# Loss after  9090  epochs :  12.497409576516706
# Loss after  9100  epochs :  12.496352528521493
# Loss after  9110  epochs :  12.495298243428746
# Loss after  9120  epochs :  12.494246708907891
# Loss after  9130  epochs :  12.493197912697468
# Loss after  9140  epochs :  12.492151842604711
# Loss after  9150  epochs :  12.491108486505127
# Loss after  9160  epochs :  12.490067832342067
# Loss after  9170  epochs :  12.489029868126336
# Loss after  9180  epochs :  12.487994581935757
# Loss after  9190  epochs :  12.48696196191477
# Loss after  9200  epochs :  12.485931996274033
# Loss after  9210  epochs :  12.484904673290009
# Loss after  9220  epochs :  12.483879981304556
# Loss after  9230  epochs :  12.482857908724553
# Loss after  9240  epochs :  12.481838444021474
# Loss after  9250  epochs :  12.480821575731017
# Loss after  9260  epochs :  12.479807292452696
# Loss after  9270  epochs :  12.478795582849475
# Loss after  9280  epochs :  12.477786435647348
# Loss after  9290  epochs :  12.476779839634986
# Loss after  9300  epochs :  12.475775783663341
# Loss after  9310  epochs :  12.474774256645265
# Loss after  9320  epochs :  12.47377524755514
# Loss after  9330  epochs :  12.472778745428514
# Loss after  9340  epochs :  12.471784739361691
# Loss after  9350  epochs :  12.47079321851141
# Loss after  9360  epochs :  12.469804172094452
# Loss after  9370  epochs :  12.468817589387271
# Loss after  9380  epochs :  12.46783345972565
# Loss after  9390  epochs :  12.46685177250432
# Loss after  9400  epochs :  12.465872517176626
# Loss after  9410  epochs :  12.464895683254154
# Loss after  9420  epochs :  12.463921260306378
# Loss after  9430  epochs :  12.462949237960322
# Loss after  9440  epochs :  12.46197960590021
# Loss after  9450  epochs :  12.461012353867092
# Loss after  9460  epochs :  12.460047471658543
# Loss after  9470  epochs :  12.459084949128291
# Loss after  9480  epochs :  12.45812477618589
# Loss after  9490  epochs :  12.457166942796373
# Loss after  9500  epochs :  12.456211438979931
# Loss after  9510  epochs :  12.455258254811563
# Loss after  9520  epochs :  12.454307380420756
# Loss after  9530  epochs :  12.453358805991154
# Loss after  9540  epochs :  12.45241252176023
# Loss after  9550  epochs :  12.451468518018965
# Loss after  9560  epochs :  12.450526785111515
# Loss after  9570  epochs :  12.449587313434902
# Loss after  9580  epochs :  12.448650093438687
# Loss after  9590  epochs :  12.447715115624668
# Loss after  9600  epochs :  12.446782370546533
# Loss after  9610  epochs :  12.445851848809589
# Loss after  9620  epochs :  12.444923541070427
# Loss after  9630  epochs :  12.44399743803661
# Loss after  9640  epochs :  12.44307353046638
# Loss after  9650  epochs :  12.44215180916835
# Loss after  9660  epochs :  12.44123226500119
# Loss after  9670  epochs :  12.440314888873344
# Loss after  9680  epochs :  12.439399671742718
# Loss after  9690  epochs :  12.438486604616385
# Loss after  9700  epochs :  12.437575678550292
# Loss after  9710  epochs :  12.436666884648975
# Loss after  9720  epochs :  12.435760214065246
# Loss after  9730  epochs :  12.434855657999924
# Loss after  9740  epochs :  12.433953207701538
# Loss after  9750  epochs :  12.433052854466045
# Loss after  9760  epochs :  12.432154589636538
# Loss after  9770  epochs :  12.431258404602978
# Loss after  9780  epochs :  12.430364290801897
# Loss after  9790  epochs :  12.429472239716132
# Loss after  9800  epochs :  12.428582242874542
# Loss after  9810  epochs :  12.427694291851731
# Loss after  9820  epochs :  12.42680837826778
# Loss after  9830  epochs :  12.425924493787972
# Loss after  9840  epochs :  12.425042630122528
# Loss after  9850  epochs :  12.424162779026322
# Loss after  9860  epochs :  12.423284932298634
# Loss after  9870  epochs :  12.422409081782874
# Loss after  9880  epochs :  12.421535219366323
# Loss after  9890  epochs :  12.420663336979864
# Loss after  9900  epochs :  12.419793426597733
# Loss after  9910  epochs :  12.418925480237254
# Loss after  9920  epochs :  12.418059489958585
# Loss after  9930  epochs :  12.417195447864456
# Loss after  9940  epochs :  12.416333346099924
# Loss after  9950  epochs :  12.41547317685212
# Loss after  9960  epochs :  12.414614932349991
# Loss after  9970  epochs :  12.413758604864062
# Loss after  9980  epochs :  12.412904186706184
# Loss after  9990  epochs :  12.412051670229278
# Train Error for learning_rate = 0.01 :  12.411201047827117  Test error for learning_rate = 0.01 :  9.104068692758704
# Loss after  0  epochs :  282.04502069891436
# Loss after  10  epochs :  266.14294155248143
# Loss after  20  epochs :  251.36713579017677
# Loss after  30  epochs :  237.63702281075953
# Loss after  40  epochs :  224.8777920484779
# Loss after  50  epochs :  213.0199897741631
# Loss after  60  epochs :  201.99913548618025
# Loss after  70  epochs :  191.75536577225446
# Loss after  80  epochs :  182.2331036749378
# Loss after  90  epochs :  173.3807517343571
# Loss after  100  epochs :  165.15040701267282
# Loss after  110  epochs :  157.49759652610118
# Loss after  120  epochs :  150.38103162307945
# Loss after  130  epochs :  143.76237995180884
# Loss after  140  epochs :  137.60605375757035
# Loss after  150  epochs :  131.8790133404097
# Loss after  160  epochs :  126.55058458753315
# Loss after  170  epochs :  121.59228957249952
# Loss after  180  epochs :  116.97768928547247
# Loss after  190  epochs :  112.68223762580865
# Loss after  200  epochs :  108.68314585046595
# Loss after  210  epochs :  104.95925672947256
# Loss after  220  epochs :  101.49092771331898
# Loss after  230  epochs :  98.25992246691273
# Loss after  240  epochs :  95.24931017095298
# Loss after  250  epochs :  92.44337203448661
# Loss after  260  epochs :  89.82751450224094
# ...
# Loss after  6600  epochs :  26.75774432320992
# Loss after  6610  epochs :  26.744164546309474
# Loss after  6620  epochs :  26.7306102183723
# Loss after  6630  epochs :  26.71708123433981
# Loss after  6640  epochs :  26.703577489775995
# Loss after  6650  epochs :  26.69009888086333
# Loss after  6660  epochs :  26.676645304398853
# Loss after  6670  epochs :  26.663216657790116
# Loss after  6680  epochs :  26.64981283905128
# Loss after  6690  epochs :  26.63643374679917
# Loss after  6700  epochs :  26.623079280249375
# Loss after  6710  epochs :  26.609749339212396
# Loss after  6720  epochs :  26.59644382408978
# Loss after  8130  epochs :  24.9258744868961
# Loss after  8140  epochs :  24.915257596517595
# Loss after  8150  epochs :  24.904655446311647
# Loss after  8160  epochs :  24.894067991956078
# Loss after  8170  epochs :  24.883495189361962
# Loss after  8180  epochs :  24.87293699467215
# Loss after  8190  epochs :  24.862393364259816
# Loss after  8200  epochs :  24.85186425472701
# Loss after  8210  epochs :  24.841349622903216
# Loss after  8220  epochs :  24.830849425843905
# Loss after  8230  epochs :  24.82036362082915
# Loss after  8240  epochs :  24.809892165362164
# Loss after  8250  epochs :  24.799435017167962
# Loss after  8260  epochs :  24.788992134191894
# Loss after  8270  epochs :  24.77856347459832
# Loss after  8280  epochs :  24.768148996769206
# Loss after  8290  epochs :  24.757748659302766
# Loss after  8300  epochs :  24.7473624210121
# Loss after  8310  epochs :  24.736990240923838
# Loss after  8320  epochs :  24.726632078276833
# Loss after  8330  epochs :  24.716287892520793
# Loss after  8340  epochs :  24.70595764331496
# Loss after  8350  epochs :  24.69564129052684
# Loss after  8360  epochs :  24.68533879423084
# Loss after  8370  epochs :  24.675050114707016
# Loss after  8380  epochs :  24.664775212439757
# Loss after  8390  epochs :  24.65451404811653
# Loss after  8400  epochs :  24.64426658262658
# Loss after  8410  epochs :  24.634032777059698
# Loss after  8420  epochs :  24.62381259270493
# Loss after  8430  epochs :  24.613605991049376
# Loss after  8440  epochs :  24.60341293377691
# Loss after  8450  epochs :  24.593233382766982
# Loss after  8460  epochs :  24.583067300093372
# Loss after  8470  epochs :  24.57291464802298
# Loss after  8480  epochs :  24.562775389014643
# Loss after  8490  epochs :  24.55264948571791
# Loss after  8500  epochs :  24.54253690097185
# Loss after  8510  epochs :  24.532437597803895
# Loss after  8520  epochs :  24.52235153942865
# Loss after  8530  epochs :  24.512278689246724
# Loss after  8540  epochs :  24.50221901084356
# Loss after  8550  epochs :  24.492172467988325
# Loss after  8560  epochs :  24.482139024632705
# Loss after  8570  epochs :  24.472118644909816
# Loss after  8580  epochs :  24.462111293133052
# Loss after  8590  epochs :  24.452116933794983
# Loss after  8600  epochs :  24.4421355315662
# Loss after  8610  epochs :  24.432167051294257
# Loss after  8620  epochs :  24.42221145800254
# Loss after  8630  epochs :  24.412268716889184
# Loss after  8640  epochs :  24.402338793325963
# Loss after  8650  epochs :  24.392421652857266
# Loss after  8660  epochs :  24.382517261198977
# Loss after  8670  epochs :  24.37262558423741
# Loss after  8680  epochs :  24.36274658802829
# Loss after  8690  epochs :  24.35288023879567
# Loss after  8700  epochs :  24.343026502930883
# Loss after  8710  epochs :  24.33318534699153
# Loss after  8720  epochs :  24.32335673770044
# Loss after  8730  epochs :  24.31354064194462
# Loss after  8740  epochs :  24.303737026774293
# Loss after  8750  epochs :  24.293945859401834
# Loss after  8760  epochs :  24.28416710720079
# Loss after  8770  epochs :  24.274400737704884
# Loss after  8780  epochs :  24.264646718607015
# Loss after  8790  epochs :  24.25490501775829
# Loss after  8800  epochs :  24.24517560316702
# Loss after  8810  epochs :  24.235458442997775
# Loss after  8820  epochs :  24.225753505570403
# Loss after  8830  epochs :  24.216060759359078
# Loss after  8840  epochs :  24.20638017299135
# Loss after  8850  epochs :  24.19671171524718
# Loss after  8860  epochs :  24.187055355058025
# Loss after  8870  epochs :  24.177411061505893
# Loss after  8880  epochs :  24.167778803822404
# Loss after  8890  epochs :  24.1581585513879
# Loss after  8900  epochs :  24.14855027373048
# Loss after  8910  epochs :  24.13895394052513
# Loss after  8920  epochs :  24.12936952159282
# Loss after  8930  epochs :  24.119796986899583
# Loss after  8940  epochs :  24.11023630655562
# Loss after  8950  epochs :  24.100687450814444
# Loss after  8960  epochs :  24.091150390071977
# Loss after  8970  epochs :  24.081625094865675
# Loss after  8980  epochs :  24.07211153587366
# Loss after  8990  epochs :  24.062609683913877
# Loss after  9000  epochs :  24.053119509943198
# Loss after  9010  epochs :  24.043640985056605
# Loss after  9020  epochs :  24.034174080486324
# Loss after  9030  epochs :  24.024718767600987
# Loss after  9040  epochs :  24.015275017904806
# Loss after  9050  epochs :  24.005842803036714
# Loss after  9060  epochs :  23.996422094769585
# Loss after  9070  epochs :  23.98701286500938
# Loss after  9080  epochs :  23.977615085794344
# Loss after  9090  epochs :  23.96822872929419
# Loss after  9100  epochs :  23.958853767809305
# Loss after  9110  epochs :  23.949490173769952
# Loss after  9120  epochs :  23.94013791973547
# Loss after  9130  epochs :  23.930796978393477
# Loss after  9140  epochs :  23.921467322559124
# Loss after  9150  epochs :  23.912148925174268
# Loss after  9160  epochs :  23.90284175930674
# Loss after  9170  epochs :  23.893545798149542
# Loss after  9180  epochs :  23.88426101502012
# Loss after  9190  epochs :  23.87498738335959
# Loss after  9200  epochs :  23.86572487673196
# Loss after  9210  epochs :  23.85647346882343
# Loss after  9220  epochs :  23.847233133441623
# Loss after  9230  epochs :  23.838003844514834
# Loss after  9240  epochs :  23.828785576091327
# Loss after  9250  epochs :  23.819578302338574
# Loss after  9260  epochs :  23.810381997542564
# Loss after  9270  epochs :  23.801196636107058
# Loss after  9280  epochs :  23.79202219255289
# Loss after  9290  epochs :  23.78285864151725
# Loss after  9300  epochs :  23.773705957752963
# Loss after  9310  epochs :  23.764564116127843
# Loss after  9320  epochs :  23.755433091623917
# Loss after  9330  epochs :  23.746312859336786
# Loss after  9340  epochs :  23.737203394474946
# Loss after  9350  epochs :  23.728104672359073
# Loss after  9360  epochs :  23.719016668421354
# Loss after  9370  epochs :  23.709939358204828
# Loss after  9380  epochs :  23.700872717362696
# Loss after  9390  epochs :  23.691816721657666
# Loss after  9400  epochs :  23.682771346961307
# Loss after  9410  epochs :  23.673736569253343
# Loss after  9420  epochs :  23.664712364621074
# Loss after  9430  epochs :  23.65569870925867
# Loss after  9440  epochs :  23.64669557946654
# Loss after  9450  epochs :  23.637702951650713
# Loss after  9460  epochs :  23.628720802322174
# Loss after  9470  epochs :  23.619749108096265
# Loss after  9480  epochs :  23.61078784569202
# Loss after  9490  epochs :  23.601836991931577
# Loss after  9500  epochs :  23.59289652373952
# Loss after  9510  epochs :  23.583966418142314
# Loss after  9520  epochs :  23.575046652267655
# Loss after  9530  epochs :  23.566137203343875
# Loss after  9540  epochs :  23.55723804869933
# Loss after  9550  epochs :  23.548349165761827
# Loss after  9560  epochs :  23.53947053205799
# Loss after  9570  epochs :  23.530602125212702
# Loss after  9580  epochs :  23.521743922948506
# Loss after  9590  epochs :  23.512895903085003
# Loss after  9600  epochs :  23.504058043538308
# Loss after  9610  epochs :  23.49523032232044
# Loss after  9620  epochs :  23.486412717538776
# Loss after  9630  epochs :  23.477605207395445
# Loss after  9640  epochs :  23.468807770186814
# Loss after  9650  epochs :  23.460020384302876
# Loss after  9660  epochs :  23.451243028226735
# Loss after  9670  epochs :  23.442475680534013
# Loss after  9680  epochs :  23.433718319892343
# Loss after  9690  epochs :  23.424970925060766
# Loss after  9700  epochs :  23.41623347488923
# Loss after  9710  epochs :  23.407505948318054
# Loss after  9720  epochs :  23.39878832437735
# Loss after  9730  epochs :  23.390080582186535
# Loss after  9740  epochs :  23.38138270095376
# Loss after  9750  epochs :  23.37269465997542
# Loss after  9760  epochs :  23.36401643863562
# Loss after  9770  epochs :  23.355348016405642
# Loss after  9780  epochs :  23.346689372843432
# Loss after  9790  epochs :  23.33804048759311
# Loss after  9800  epochs :  23.329401340384425
# Loss after  9810  epochs :  23.32077191103229
# Loss after  9820  epochs :  23.312152179436236
# Loss after  9830  epochs :  23.303542125579945
# Loss after  9840  epochs :  23.294941729530727
# Loss after  9850  epochs :  23.286350971439063
# Loss after  9860  epochs :  23.27776983153808
# Loss after  9870  epochs :  23.269198290143073
# Loss after  9880  epochs :  23.26063632765103
# Loss after  9890  epochs :  23.252083924540152
# Loss after  9900  epochs :  23.243541061369356
# Loss after  9910  epochs :  23.235007718777833
# Loss after  9920  epochs :  23.226483877484547
# Loss after  9930  epochs :  23.217969518287774
# Loss after  9940  epochs :  23.20946462206465
# Loss after  9950  epochs :  23.20096916977069
# Loss after  9960  epochs :  23.192483142439347
# Loss after  9970  epochs :  23.18400652118154
# Loss after  9980  epochs :  23.175539287185213
# Loss after  9990  epochs :  23.167081421714865
# Train Error for learning_rate = 0.001 :  23.158632906111126  Test error for learning_rate = 0.001 :  14.9732788654663

# %% [markdown]
# ## Task: Submitting Your Predictions
#
# After training your Linear Regression model on the provided training dataset, you have generate predictions for the test dataset named `housing_test.csv`, your final task is to save the predicted values for the test dataset in a file named `RollNo_Linear.csv`.
#
# ### Instructions for Submission:
# 1. **Format**:
#    The `RollNo_Linear.csv` file should contain one prediction per line, corresponding to the order of the test dataset features provided to you. Ensure there are no extra spaces, commas, or blank lines.
#
# 2. **File Name**:
# The file must be named `RollNo_Linear.csv` exactly (case-sensitive).

# %%
"""
Write the code to save the predictions in required format
"""
### START CODE HERE ###
df_test_housing = pd.read_csv("housing_test.csv")
X_test = df_test_housing.values
X_test = min_max_scaler(X_test)
test_predictions = np.dot(X_test, w.T) + b
test_predictions = test_predictions.flatten()
df_results = pd.DataFrame()
df_results["MEDV"] = test_predictions
df_results.to_csv("22CS30054_Linear.csv", index = False)
### END CODE HERE ###
